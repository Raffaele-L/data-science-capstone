# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests # library to handle requests

#from bs4 import BeautifulSoup
import os

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests

# Matplotlib and associated plotting modules
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline
# !conda install -c anaconda pandas-profiling

#import seaborn as sns

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                  failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libstdcxx-ng conflicts for:
# py-xgboost -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# snappy -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# pyqt5-sip -> libstdcxx-ng[version='>=9.3.0']
# mkl_random -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# zfp -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# libzopfli -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# gettext -> libstdcxx-ng[version='>=7.3.0']
# pyqtchart -> libstdcxx-ng[version='>=9.3.0']
# unixodbc -> libstdcxx-ng[version='>=9.3.0']
# matplotlib-base -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# pyqt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# libxkbcommon -> libstdcxx-ng[version='>=7.5.0']
# icu -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# lz4-c -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# pytables -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# pyzmq -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# tensorboard -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# greenlet -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# blosc -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# biopython -> libstdcxx-ng[version='>=7.2.0']
# scipy -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# mysql-libs -> libstdcxx-ng[version='>=9.3.0']
# mkl_fft -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pandas -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# pyodbc -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# hdf5 -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# libclang -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# python=3.7 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# numexpr -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# charls -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# libffi -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# pyqtwebengine -> libstdcxx-ng[version='>=9.3.0']
# zeromq -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# gmp -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.5.0|>=7.3.0']
# libstdcxx-ng
# freetds -> libstdcxx-ng[version='>=9.3.0']
# pyqt-impl -> libstdcxx-ng[version='>=9.3.0']
# libnghttp2 -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# brunsli -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# brotli -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# kiwisolver -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# gst-plugins-base -> libstdcxx-ng[version='>=7.2.0|>=9.3.0|>=7.3.0']
# grpcio -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# libglib -> libstdcxx-ng[version='>=9.3.0']
# matplotlib -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# ninja -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# libllvm11 -> libstdcxx-ng[version='>=9.3.0']
# pcre -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# imagecodecs -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# scikit-learn -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# expat -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=9.3.0']
# sip -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# lerc -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# qt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# ncurses -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# nss -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# protobuf -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# pymssql -> libstdcxx-ng[version='>=9.3.0']
# scikit-image -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# tensorflow-base -> libstdcxx-ng[version='>=5.4.0|>=7.2.0']
# libvorbis -> libstdcxx-ng[version='>=9.3.0']
# libaec -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# glib -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# glib-tools -> libstdcxx-ng[version='>=9.3.0']
# libtiff -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# pytorch -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.5.0']
# krb5 -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libxgboost -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.2.0|>=9.3.0']
# openjpeg -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=9.3.0']
# nspr -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# libprotobuf -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# ibm-wsrt-py37main-main -> libstdcxx-ng==9.1.0[build=*]
# zstd -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
#
# Package python_abi conflicts for:
# cryptography -> python_abi=3.7[build=*_cp37m]
# pyqt5-sip -> python_abi=3.7[build=*_cp37m]
# ipython -> python_abi=3.7[build=*_cp37m]
# matplotlib-base -> python_abi=3.7[build=*_cp37m]
# fastcache -> python_abi=3.7[build=*_cp37m]
# pyzmq -> python_abi=3.7[build=*_cp37m]
# gmpy2 -> python_abi=3.7[build=*_cp37m]
# biopython -> python_abi=3.7[build=*_cp37m]
# yarl -> python_abi=3.7[build=*_cp37m]
# astropy -> python_abi=3.7[build=*_cp37m]
# matplotlib -> python_abi=3.7[build=*_cp37m]
# multidict -> python_abi=3.7[build=*_cp37m]
# imagecodecs -> python_abi=3.7[build=*_cp37m]
# mkl_random -> python_abi=3.7[build=*_cp37m]
# pyqtchart -> python_abi=3.7[build=*_cp37m]
# terminado -> python_abi=3.7[build=*_cp37m]
# jedi -> python_abi=3.7[build=*_cp37m]
# python_abi
# kiwisolver -> python_abi=3.7[build=*_cp37m]
# pyrsistent -> python_abi=3.7[build=*_cp37m]
# mkl_fft -> python_abi=3.7[build=*_cp37m]
# pytables -> python_abi=3.7[build=*_cp37m]
# cytoolz -> python_abi=3.7[build=*_cp37m]
# pyqtwebengine -> python_abi=3.7[build=*_cp37m]
# wrapt -> python_abi=3.7[build=*_cp37m]
# pyerfa -> python_abi=3.7[build=*_cp37m]
# pyqt -> python_abi=3.7[build=*_cp37m]
# cffi -> python_abi=3.7[build=*_cp37m]
# numpy -> python_abi=3.7[build=*_cp37m]
# chardet -> python_abi=3.7[build=*_cp37m]
# scikit-learn -> python_abi=3.7[build=*_cp37m]
# nbconvert -> python_abi=3.7[build=*_cp37m]
# argon2-cffi -> python_abi=3.7[build=*_cp37m]
# cx_oracle -> python_abi=3.7[build=*_cp37m]
# setuptools -> python_abi=3.7[build=*_cp37m]
# mkl-service -> python_abi=3.7[build=*_cp37m]
# scikit-image -> python_abi=3.7[build=*_cp37m]
# importlib-metadata -> python_abi=3.7[build=*_cp37m]
# pluggy -> python_abi=3.7[build=*_cp37m]
# secretstorage -> python_abi=3.7[build=*_cp37m]
# numexpr -> python_abi=3.7[build=*_cp37m]
# pandas -> python_abi=3.7[build=*_cp37m]
# bokeh -> python_abi=3.7[build=*_cp37m]
# pywavelets -> python_abi=3.7[build=*_cp37m]
# ipykernel -> python_abi=3.7[build=*_cp37m]
# sqlalchemy -> python_abi=3.7[build=*_cp37m]
# pillow -> python_abi=3.7[build=*_cp37m]
# protobuf -> python_abi=3.7[build=*_cp37m]
# pytest -> python_abi=3.7[build=*_cp37m]
# tornado -> python_abi=3.7[build=*_cp37m]
# tensorflow-base -> python_abi=3.7[build=*_cp37m]
# mistune -> python_abi=3.7[build=*_cp37m]
# pysocks -> python_abi=3.7[build=*_cp37m]
# jupyter_core -> python_abi=3.7[build=*_cp37m]
# markupsafe -> python_abi=3.7[build=*_cp37m]
# pymssql -> python_abi=3.7[build=*_cp37m]
# h5py -> python_abi=3.7[build=*_cp37m]
# greenlet -> python_abi=3.7[build=*_cp37m]
# aiohttp -> python_abi=3.7[build=*_cp37m]
# click -> python_abi=3.7[build=*_cp37m]
# py-xgboost -> python_abi=3.7[build=*_cp37m]
# pyqt-impl -> python_abi=3.7[build=*_cp37m]
# scipy -> python_abi=3.7[build=*_cp37m]
# grpcio -> python_abi=3.7[build=*_cp37m]
# pytorch -> python_abi=3.7[build=*_cp37m]
# future -> python_abi=3.7[build=*_cp37m]
# pyyaml -> python_abi=3.7[build=*_cp37m]
# pyodbc -> python_abi=3.7[build=*_cp37m]
# mock -> python_abi=3.7[build=*_cp37m]
# sympy -> python_abi=3.7[build=*_cp37m]
# statsmodels -> python_abi=3.7[build=*_cp37m]
# certifi -> python_abi=3.7[build=*_cp37m]
# widgetsnbextension -> python_abi=3.7[build=*_cp37m]
# lxml -> python_abi=3.7[build=*_cp37m]
# psycopg2 -> python_abi=3.7[build=*_cp37m]
# brotlipy -> python_abi=3.7[build=*_cp37m]
# regex -> python_abi=3.7[build=*_cp37m]
# sip -> python_abi=3.7[build=*_cp37m]
# docutils -> python_abi=3.7[build=*_cp37m]
#
# Package libgcc-ng conflicts for:
# wrapt -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# numpy-base -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# xorg-libxau -> libgcc-ng[version='>=9.3.0']
# matplotlib-base -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# mistune -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# statsmodels -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# greenlet -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# icu -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# tifffile -> libgcc-ng[version='>=7.3.0']
# libbrotlidec -> libgcc-ng[version='>=9.3.0']
# xz -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# libprotobuf -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# pyqt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# lerc -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# scikit-image -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libev -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# jxrlib -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# zlib -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# pyerfa -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# astropy -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libwebp-base -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# lxml -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libglib -> libgcc-ng[version='>=9.3.0']
# libzopfli -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# alsa-lib -> libgcc-ng[version='>=7.5.0']
# tensorboard -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# readline -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=9.3.0']
# numpy -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# tensorflow-base -> libgcc-ng[version='>=5.4.0|>=7.2.0']
# psycopg2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# sqlalchemy -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# qt -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# libffi -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# grpcio -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# ninja -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# jpeg -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.5.0']
# pyrsistent -> libgcc-ng[version='>=7.3.0|>=9.3.0|>=7.5.0']
# giflib -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# libvorbis -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# protobuf -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libbrotlicommon -> libgcc-ng[version='>=9.3.0']
# mpc -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.5.0']
# markupsafe -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# argon2-cffi -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# scikit-learn -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# brotlipy -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libgcc-ng
# pyqt-impl -> libgcc-ng[version='>=9.3.0']
# mysql-libs -> libgcc-ng[version='>=9.3.0']
# sip -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# xorg-libxdmcp -> libgcc-ng[version='>=9.3.0']
# brunsli -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# pyyaml -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# libiconv -> libgcc-ng[version='>=7.2.0|>=7.5.0']
# scipy -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# pcre -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# blosc -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# fastcache -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# charls -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libopus -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=9.3.0|>=7.2.0']
# pyqt5-sip -> libgcc-ng[version='>=9.3.0']
# mkl_random -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# jbig -> libgcc-ng[version='>=7.2.0|>=9.3.0']
# regex -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libnghttp2 -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libuuid -> libgcc-ng[version='>=7.2.0|>=9.3.0']
# libxkbcommon -> libgcc-ng[version='>=7.5.0']
# matplotlib -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libpq -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# dbus -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# gettext -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=9.3.0|>=7.3.0']
# ncurses -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# pyqtwebengine -> libgcc-ng[version='>=9.3.0']
# libxgboost -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.2.0|>=9.3.0']
# biopython -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# python=3.7 -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# aiohttp -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# mpfr -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libtiff -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# openjpeg -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=9.3.0']
# tk -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# sqlite -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# yaml -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# glib -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# gmpy2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# krb5 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# imagecodecs -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libogg -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libllvm11 -> libgcc-ng[version='>=9.3.0']
# c-ares -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libssh2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# freetype -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libcurl -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# zfp -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# mkl_fft -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# openssl -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# pymssql -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# cffi -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libclang -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# gmp -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.5.0|>=7.3.0']
# glib-tools -> libgcc-ng[version='>=9.3.0']
# pillow -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# zstd -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# gstreamer -> libgcc-ng[version='>=7.2.0|>=9.3.0|>=7.3.0']
# pytorch -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.5.0']
# h5py -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# gst-plugins-base -> libgcc-ng[version='>=7.2.0|>=9.3.0|>=7.3.0']
# fontconfig -> libgcc-ng[version='>=7.2.0|>=9.3.0|>=7.3.0']
# lzo -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# libaec -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# brotli-bin -> libgcc-ng[version='>=9.3.0']
# libevent -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.5.0|>=7.2.0']
# multidict -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# cx_oracle -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# kiwisolver -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# pyzmq -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# cytoolz -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# pyodbc -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# numexpr -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libxml2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# hdf5 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# mkl-service -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# nss -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# libxslt -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# cryptography -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# freetds -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# py-xgboost -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# libsodium -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# yarl -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# zeromq -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# libxcb -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# lcms2 -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# expat -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=9.3.0']
# libedit -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pyqtchart -> libgcc-ng[version='>=9.3.0']
# libdeflate -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# bzip2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# tornado -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# lz4-c -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# nspr -> libgcc-ng[version='>=7.3.0|>=9.3.0']
# cfitsio -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# pandas -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0|>=7.5.0']
# pytables -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# pthread-stubs -> libgcc-ng[version='>=7.2.0|>=7.5.0']
# unixodbc -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# libpng -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# snappy -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0|>=7.5.0']
# brotli -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# pywavelets -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=9.3.0']
# ibm-wsrt-py37main-main -> libgcc-ng==9.1.0[build=*]
#
# Package libblas conflicts for:
# libcblas -> libblas==3.9.0=8_mkl
# pytorch -> libblas[version='*|>=3.9.0,<4.0a0',build=*_mkl]
# numpy -> libblas[version='>=3.8.0,<4.0a0']
# libblas
# scipy -> libblas[version='>=3.8.0,<4.0a0']
# liblapack -> libblas==3.9.0=8_mkl
#
# Package importlib-metadata conflicts for:
# keyring -> importlib-metadata
# markdown -> importlib-metadata
# importlib_metadata -> importlib-metadata[version='>=1.1.3,<1.1.4.0a0|>=1.6.0,<1.6.1.0a0|>=1.6.1,<1.6.2.0a0|>=1.7.0,<1.7.1.0a0|>=2.0.0,<2.0.1.0a0|>=4.6.0,<4.6.1.0a0|>=3.10.0,<3.10.1.0a0|>=3.7.3,<3.7.4.0a0']
# importlib-metadata
# sqlalchemy -> importlib-metadata
# ibm-wsrt-py37main-main -> importlib-metadata==1.6.1[build=*]
# pytest -> importlib-metadata[version='>=0.12']
# click -> importlib-metadata
# jsonschema -> importlib-metadata
#
# Package six conflicts for:
# prompt-toolkit -> six[version='>=1.9.0']
# tensorflow-base -> six[version='>=1.10.0|>=1.12.0|>=1.12.0,<2.0a0|>=1.15.0']
# nltk -> six
# six
# mock -> six
# google-auth -> six[version='>=1.9.0']
# pytest -> six[version='>=1.10.0']
# patsy -> six
# absl-py -> six
# tensorflow-estimator -> six[version='>=1.10.0']
# mkl-service -> six
# tenacity -> six[version='>=1.9.0']
# grpcio -> six[version='>=1.5.2']
# more-itertools -> six[version='>=1.0.0,<2.0.0']
# bleach -> six
# bokeh -> six[version='>=1.5.2']
# argon2-cffi -> six
# html5lib -> six[version='>=1.9']
# protobuf -> six
# pyrsistent -> six
# h5py -> six
# cryptography -> six[version='>=1.4.1']
# google-pasta -> six
# arcgis=1.6.0 -> six
# altair -> six
# pytables -> six
# branca -> six
# pandas-profiling -> six[version='>=1.9']
# packaging -> six
# traitlets -> six
# tensorboard -> six[version='>=1.10.0|>=1.12']
# jsonschema -> six[version='>=1.11.0']
# ibm-wsrt-py37main-main -> six==1.15.0[build=*]
# scikit-image -> six[version='>=1.7.3']
# keras-preprocessing -> six[version='>=1.9.0']
# python-dateutil -> six[version='>=1.5']
# retrying -> six[version='>=1.7.0']
# plotly -> six==1.15.0
# cycler -> six
# pyopenssl -> six[version='>=1.5.2']
# pyu2f -> six
#
# Package pyopenssl conflicts for:
# pyopenssl
# urllib3 -> pyopenssl[version='>=0.14']
# google-auth -> pyopenssl[version='>=20.0.0']
# ibm-wsrt-py37main-main -> pyopenssl==19.1.0[build=*]
#
# Package ptyprocess conflicts for:
# ibm-wsrt-py37main-main -> ptyprocess==0.6.0[build=*]
# ptyprocess
# pexpect -> ptyprocess[version='>=0.5']
# terminado -> ptyprocess
#
# Package qt conflicts for:
# ibm-wsrt-py37main-main -> qt==5.9.7[build=*]
# pyqtwebengine -> qt[version='>=5.12.9,<5.13.0a0']
# pyqtchart -> qt[version='>=5.12.9,<5.13.0a0']
# qt
# pyqt -> qt[version='5.6.*|5.9.*|>=5.9.7,<5.10.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0|>=5.6.3,<5.7.0a0']
# pyqt-impl -> qt[version='>=5.12.9,<5.13.0a0']
#
# Package snappy conflicts for:
# snappy
# ibm-wsrt-py37main-main -> snappy==1.1.8[build=*]
# imagecodecs -> snappy[version='>=1.1.8,<2.0a0']
# blosc -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
# tensorflow-base -> snappy[version='>=1.1.8,<2.0a0']
#
# Package botocore conflicts for:
# botocore
# ibm-wsrt-py37main-main -> botocore==1.16.11[build=*]
# ibm-wsrt-py37main-keep -> botocore=[build=*]
# boto3 -> botocore[version='>=1.10.24,<1.11.0|>=1.10.32,<1.11.0|>=1.10.45,<1.11.0|>=1.10.62,<1.11.0|>=1.11.2,<1.12.0|>=1.12.111,<1.13.0|>=1.12.134,<1.13.0|>=1.12.162,<1.13.0|>=1.12.199,<1.13.0|>=1.12.234,<1.13.0|>=1.13.13,<1.14.0|>=1.13.19,<1.14.0|>=1.13.39,<1.14.0|>=1.14.0,<1.15.0|>=1.14.14,<1.15.0|>=1.15.0,<1.16.0|>=1.15.12,<1.16.0|>=1.15.39,<1.16.0|>=1.16.11,<1.17.0|>=1.17.12,<1.18.0|>=1.17.31,<1.18.0|>=1.17.37,<1.18.0|>=1.17.39,<1.18.0|>=1.17.43,<1.18.0|>=1.17.45,<1.18.0|>=1.17.48,<1.18.0|>=1.17.49,<1.18.0|>=1.17.50,<1.18.0|>=1.17.51,<1.18.0|>=1.17.52,<1.18.0|>=1.17.53,<1.18.0|>=1.17.54,<1.18.0|>=1.17.55,<1.18.0|>=1.17.56,<1.18.0|>=1.17.57,<1.18.0|>=1.17.58,<1.18.0|>=1.17.59,<1.18.0|>=1.17.60,<1.18.0|>=1.17.63,<1.18.0|>=1.18.0,<1.19.0|>=1.18.1,<1.19.0|>=1.18.10,<1.19.0|>=1.18.11,<1.19.0|>=1.18.12,<1.19.0|>=1.18.13,<1.19.0|>=1.18.14,<1.19.0|>=1.18.15,<1.19.0|>=1.18.16,<1.19.0|>=1.19.0,<1.20.0|>=1.18.9,<1.19.0|>=1.18.8,<1.19.0|>=1.18.7,<1.19.0|>=1.18.5,<1.19.0|>=1.18.4,<1.19.0|>=1.18.3,<1.19.0|>=1.18.2,<1.19.0|>=1.12.82,<1.13.0|>=1.12.66,<1.13.0|>=1.12.35,<1.13.0|>=1.12.21,<1.13.0|>=1.12.13,<1.13.0|>=1.12.7,<1.13.0|>=1.10.4,<1.11.0|>=1.9.18,<1.10.0|>=1.8.46,<1.9.0|>=1.8.0,<1.9.0|>=1.7.0,<1.8.0|>=1.20.104,<1.21.0|>=1.20.101,<1.21.0|>=1.20.97,<1.21.0|>=1.20.88,<1.21.0|>=1.20.46,<1.21.0|>=1.20.41,<1.21.0|>=1.20.40,<1.21.0|>=1.20.28,<1.21.0|>=1.20.27,<1.21.0|>=1.20.23,<1.21.0|>=1.20.22,<1.21.0|>=1.20.21,<1.21.0|>=1.20.20,<1.21.0|>=1.20.19,<1.21.0|>=1.20.18,<1.21.0|>=1.20.16,<1.21.0|>=1.20.12,<1.21.0|>=1.20.11,<1.21.0|>=1.20.10,<1.21.0|>=1.20.9,<1.21.0|>=1.20.8,<1.21.0|>=1.20.7,<1.21.0|>=1.19.63,<1.20.0|>=1.19.62,<1.20.0|>=1.19.61,<1.20.0|>=1.19.60,<1.20.0|>=1.19.59,<1.20.0|>=1.19.58,<1.20.0|>=1.19.55,<1.20.0|>=1.19.54,<1.20.0|>=1.19.53,<1.20.0|>=1.19.52,<1.20.0|>=1.19.50,<1.20.0|>=1.19.49,<1.20.0|>=1.19.48,<1.20.0|>=1.19.47,<1.20.0|>=1.19.45,<1.20.0|>=1.19.44,<1.20.0|>=1.19.43,<1.20.0|>=1.19.42,<1.20.0|>=1.19.41,<1.20.0|>=1.19.39,<1.20.0|>=1.19.36,<1.20.0|>=1.19.35,<1.20.0|>=1.19.34,<1.20.0|>=1.19.33,<1.20.0|>=1.19.32,<1.20.0|>=1.19.30,<1.20.0|>=1.19.29,<1.20.0|>=1.19.28,<1.20.0|>=1.19.27,<1.20.0|>=1.19.25,<1.20.0|>=1.19.24,<1.20.0|>=1.19.23,<1.20.0|>=1.19.15,<1.20.0|>=1.19.9,<1.20.0|>=1.19.7,<1.20.0|>=1.19.6,<1.20.0|>=1.19.3,<1.20.0']
# s3transfer -> botocore[version='>=1.12.36,<2.0.0|>=1.3.0,<2.0.0|>=1.12.36,<2.0a.0']
#
# Package termcolor conflicts for:
# tensorflow-estimator -> termcolor[version='>=1.1.0']
# tensorflow-base -> termcolor[version='>=1.1.0|>=1.1.0,<2.0a0']
# ibm-wsrt-py37main-main -> termcolor==1.1.0[build=*]
# termcolor
#
# Package pyzmq conflicts for:
# ipykernel -> pyzmq!=21
# pyzmq
# notebook -> pyzmq[version='>=17']
# ibm-wsrt-py37main-main -> pyzmq==19.0.1[build=*]
# jupyter_client -> pyzmq[version='>=13']
#
# Package numpy conflicts for:
# keras-preprocessing -> numpy[version='>=1.9.1']
# nltk -> numpy
# statsmodels -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.17.0,<2.0a0|>=1.19.1,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0|>=1.19.2,<2.0a0']
# tifffile -> numpy[version='>=1.11.3,<2.0a0|>=1.15.1|>=1.14.6,<2.0a0']
# arcgis=1.6.0 -> numpy
# tensorflow-estimator -> numpy[version='>=1.13.3|>=1.16.1']
# bokeh -> numpy[version='>=1.11.3|>=1.7.1']
# numpy
# mkl_random -> numpy[version='>=1.11.3,<2.0a0|>=1.14,<2.0a0|>=1.14.6,<2.0a0|>=1.16.5,<2.0a0|>=1.16,<2.0a0']
# opt_einsum -> numpy
# pandas-profiling -> numpy[version='>=1.16.0']
# tensorboard -> numpy[version='>=1.12|>=1.12.0|>=1.16']
# tensorflow-base -> numpy[version='>=1.12.1,<2.0a0|>=1.13.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0|>=1.16.1,<2.0a0|>=1.20']
# scipy -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.15.1,<2.0a0|>=1.9.3,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0']
# pyerfa -> numpy[version='>=1.17.0,<2.0a0|>=1.17|>=1.17.5,<2.0a0|>=1.20.1,<2.0a0|>=1.19.2,<2.0a0']
# pywavelets -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0']
# scikit-image -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0|>=1.13.3,<2.0a0']
# altair -> numpy[version='>=0.18']
# folium=0.5.0 -> numpy
# astropy -> numpy[version='>=1.10.4,<2.0a0|>=1.11.3,<2.0a0|>=1.13.3,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0|>=1.17.4,<2.0a0|>=1.14.6,<2.0a0|>=1.11|>=1.9|>=1.14|>=1.9.3,<2.0a0|>=1.14.1,<2.0a0|>=1.14.0,<2.0a0|>=1.17|>=1.17.5,<2.0a0|>=1.17.0,<2.0a0']
# seaborn -> numpy[version='>=1.13.3|>=1.9.3']
# numexpr -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.4,<2.0a0|>=1.15.4,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0']
# matplotlib-base -> numpy[version='>=1.14.6,<2.0a0|>=1.15.4,<2.0a0|>=1.16.6,<2.0a0|>=1.17.5,<2.0a0']
# mkl_fft -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.16,<2.0a0']
# matplotlib -> numpy[version='>=1.14.6,<2.0a0']
# py-xgboost -> numpy
# ibm-wsrt-py37main-main -> numpy==1.18.5[build=*]
# pandas -> numpy[version='>=1.11.3,<2.0a0|>=1.12.1,<2.0a0|>=1.13.3,<2.0a0|>=1.14.6,<2.0a0|>=1.15.4,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0|>=1.9|>=1.17.5,<2.0a0|>=1.20.2,<2.0a0|>=1.19.2,<2.0a0']
# mkl-service -> numpy[version='>=1.11.3,<2.0a0']
# scikit-learn -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.17.5,<2.0a0|>=1.16.6,<2.0a0']
# pytorch -> numpy[version='>=1.11|>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.9|>=1.16.6,<2.0a0']
# biopython -> numpy[version='>=1.11.3,<2.0a0|>=1.9.3,<2.0a0|>=1.14.1,<2.0a0']
# h5py -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.17.5,<2.0a0|>=1.16.6,<2.0a0']
# patsy -> numpy[version='>=1.4.0']
# pytables -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0']
# seaborn-base -> numpy[version='>=1.15']
# imageio -> numpy
# imagecodecs -> numpy[version='>=1.15.4,<2.0a0|>=1.16.6,<2.0a0|>=1.17.5,<2.0a0']
# keras-applications -> numpy[version='>=1.9.1']
#
# Package pyasn1-modules conflicts for:
# ibm-wsrt-py37main-main -> pyasn1-modules==0.2.8[build=*]
# pyasn1-modules
# google-auth -> pyasn1-modules[version='>=0.2.1']
#
# Package keras-applications conflicts for:
# ibm-wsrt-py37main-main -> keras-applications==1.0.8[build=*]
# tensorflow-base -> keras-applications[version='>=1.0.5|>=1.0.6|>=1.0.8|>=1.0.8,<2.0a0']
# keras-applications
#
# Package cudnn conflicts for:
# tensorflow-base -> cudnn[version='7.*|7.0.*|7.1.*|7.2.*|>=7.3.1,<8.0a0|>=7.6,<8.0a0|>=7.6.5,<8.0a0|>=7.6.0,<8.0a0|>=7.6.4,<8.0a0|>=7.2.0,<=8.0a0|>=7.1.0,<=8.0a0|>=7.0.0,<=8.0a0|>=7.1.2,<=8.0a0|>=7.0.5,<=8.0a0']
# pytorch -> cudnn[version='5.1.*|6.0.*|7.*|7.1.*|7.3.*|>=7.6,<8.0a0|>=7.6.5,<8.0a0|>=7.6.4,<8.0a0|>=7.3.1,<8.0a0|>=7.1.3,<8.0a0|7.0.*|>=7.3.0,<=8.0a0|>=7.1.0,<=8.0a0|>=7.1.2,<=8.0a0|>=7.0.5,<=8.0a0|>=7.0.0,<=8.0a0']
#
# Package nbformat conflicts for:
# ibm-wsrt-py37main-main -> nbformat==5.0.7[build=*]
# plotly -> nbformat[version='>=4.2']
# ipywidgets -> nbformat[version='>=4.2.0']
# nbclient -> nbformat[version='>=5.0']
# notebook -> nbformat
# nbconvert -> nbformat[version='>=4.4']
# nbformat
#
# Package certifi conflicts for:
# certifi
# ibm-wsrt-py37main-main -> certifi==2021.5.30[build=*]
# urllib3 -> certifi
# requests -> certifi[version='>=2017.4.17']
# matplotlib-base -> certifi[version='>=2020.06.20']
# tornado -> certifi
# setuptools -> certifi[version='>=2016.09|>=2016.9.26']
#
# Package futures conflicts for:
# tenacity -> futures[version='>=3']
# bokeh -> futures[version='>=3.0.3']
# grpcio -> futures[version='>=2.2.0']
# imageio -> futures
# tornado -> futures
# s3transfer -> futures[version='>=2.2.0,<4.0.0']
# tensorboard -> futures[version='>=3.1.1']
# jupyterlab -> futures
#
# Package matplotlib-base conflicts for:
# pandas-profiling -> matplotlib-base[version='>=3.2.0']
# scikit-image -> matplotlib-base[version='>=2.0.0']
# matplotlib-base
# seaborn-base -> matplotlib-base[version='>=2.2']
# ibm-wsrt-py37main-main -> matplotlib-base==3.2.2[build=*]
# matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.4.2,<3.4.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.3.2,<3.3.3.0a0',build='py37hef1b27d_1|py36hef1b27d_1|py37hef1b27d_0|py36hef1b27d_0|py38hef1b27d_0|py38hef1b27d_1']
#
# Package notebook conflicts for:
# jupyterlab_server -> notebook[version='>=4.2.0']
# arcgis=1.6.0 -> notebook
# widgetsnbextension -> notebook[version='>=4.4.1']
# ibm-wsrt-py37main-main -> notebook==6.0.3[build=*]
# notebook
# jupyterlab -> notebook[version='>=4.3|>=4.3.1']
#
# Package libpng conflicts for:
# qt -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0|>=1.6.35,<1.7.0a0|>=1.6.37,<1.7.0a0']
# tensorflow-base -> libpng[version='>=1.6.37,<1.7.0a0']
# matplotlib-base -> libpng[version='>=1.6.37,<1.7.0a0']
# imagecodecs -> libpng[version='>=1.6.37,<1.7.0a0']
# matplotlib -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0|>=1.6.35,<1.7.0a0|>=1.6.36,<1.7.0a0|>=1.6.37,<1.7.0a0']
# openjpeg -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0|>=1.6.37,<1.7.0a0']
# libpng
# fontconfig -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0']
# freetype -> libpng[version='>=1.6.32,<1.7.0a0|>=1.6.34,<1.7.0a0|>=1.6.37,<1.7.0a0']
# ibm-wsrt-py37main-main -> libpng==1.6.37[build=*]
# gst-plugins-base -> libpng[version='>=1.6.37,<1.7.0a0']
#
# Package ipython conflicts for:
# ibm-wsrt-py37main-main -> ipython==7.15.0[build=*]
# jupyterlab -> ipython
# ipywidgets -> ipython[version='>=4.0.0']
# ipython
# ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0']
#
# Package ninja conflicts for:
# ibm-wsrt-py37main-main -> ninja==1.9.0[build=*]
# pytorch -> ninja
# ninja
#
# Package openssl conflicts for:
# freetds -> openssl[version='>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1e,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1a,<1.1.2a']
# grpcio -> openssl[version='>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1a,<1.1.2a']
# libnghttp2 -> openssl[version='>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a']
# python=3.7 -> openssl[version='>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a']
# libpq -> openssl[version='>=1.0.2m,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1k,<1.1.2a']
# qt -> openssl[version='1.0.*|1.1.*|>=1.0.2p,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.1.1j,<1.1.2a']
# tensorflow-base -> openssl[version='>=1.1.1k,<1.1.2a']
# psycopg2 -> openssl[version='1.0.*|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.0.2m,<1.0.3a']
# libevent -> openssl[version='>=1.0.2m,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1a,<1.1.2a']
# ibm-wsrt-py37main-main -> openssl==1.1.1k[build=*]
# openssl
# mysql-libs -> openssl[version='>=1.1.1k,<1.1.2a']
# krb5 -> openssl[version='1.0.*|>=1.0.2l,<1.0.3a|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1a,<1.1.2a']
# libssh2 -> openssl[version='>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1b,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1a,<1.1.2a']
# cryptography -> openssl[version='1.0.*|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2n,<1.0.3a|>=1.0.2m,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1i,<1.1.2a']
# hdf5 -> openssl[version='>=1.1.1h,<1.1.2a']
# libcurl -> openssl[version='>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1k,<1.1.2a']
#
# Package jupyter_core conflicts for:
# jupyterlab -> jupyter_core
# nbconvert -> jupyter_core
# jupyter_core
# notebook -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# ibm-wsrt-py37main-main -> jupyter_core==4.6.3[build=*]
# nbformat -> jupyter_core
# jupyter_client -> jupyter_core[version='>=4.6.0']
#
# Package libbrotlicommon conflicts for:
# libbrotlidec -> libbrotlicommon==1.0.9=h7f98852_5
# libbrotlicommon
#
# Package libsodium conflicts for:
# pyzmq -> libsodium[version='>=1.0.16,<1.0.17.0a0|>=1.0.18,<1.0.19.0a0']
# libsodium
# ibm-wsrt-py37main-main -> libsodium==1.0.18[build=*]
# zeromq -> libsodium[version='>=1.0.16,<1.0.17.0a0|>=1.0.18,<1.0.19.0a0']
#
# Package lzo conflicts for:
# pytables -> lzo[version='2.*|>=2.10,<3.0a0']
# lzo
# ibm-wsrt-py37main-main -> lzo==2.10[build=*]
#
# Package libdeflate conflicts for:
# imagecodecs -> libdeflate[version='>=1.7,<1.8.0a0']
# libdeflate
# libtiff -> libdeflate[version='>=1.7,<1.8.0a0']
#
# Package libgfortran-ng conflicts for:
# hdf5 -> libgfortran-ng[version='7.2.0.*|>=7,<8.0a0|>=7.2.0|>=7.2.0,<8.0a0']
# cfitsio -> libgfortran-ng[version='>=7,<8.0a0']
# ibm-wsrt-py37main-main -> libgfortran-ng==7.3.0[build=*]
# numpy -> libgfortran-ng[version='7.2.0.*|>=7,<8.0a0|>=7.2.0|>=7.2.0,<8.0a0']
# numpy-base -> libgfortran-ng[version='>=7,<8.0a0']
# scipy -> libgfortran-ng[version='7.2.0.*|>=7,<8.0a0|>=7.2.0|>=7.2.0,<8.0a0']
# libgfortran-ng
#
# Package markdown conflicts for:
# tensorboard -> markdown[version='>=2.6.11|>=2.6.8']
# tensorflow-base -> markdown[version='>=2.6.11']
# ibm-wsrt-py37main-main -> markdown==3.1.1[build=*]
# markdown
#
# Package numexpr conflicts for:
# pandas -> numexpr[version='>=2.6.8']
# ibm-wsrt-py37main-main -> numexpr==2.7.1[build=*]
# pytables -> numexpr
# numexpr
#
# Package typing_extensions conflicts for:
# aiohttp -> typing_extensions[version='>=3.6.5']
# pytorch -> typing_extensions
# typing-extensions -> typing_extensions[version='3.10.0.0|3.10.0.0|3.7.4|3.7.4.1|3.7.4.2|3.7.4.3|3.7.4.3',build='pyha770c72_0|py_0|py38_0|py36_0|pyh06a4308_0|pyh06a4308_0']
# tensorflow-base -> typing_extensions[version='>=3.7.4']
# bokeh -> typing_extensions[version='>=3.7.4']
# typing_extensions
# ibm-wsrt-py37main-main -> typing_extensions==3.7.4.2[build=*]
# importlib-metadata -> typing_extensions[version='>=3.6.4']
#
# Package absl-py conflicts for:
# ibm-wsrt-py37main-main -> absl-py==0.9.0[build=*]
# tensorboard -> absl-py[version='>=0.4|>=0.7']
# absl-py
# tensorflow-base -> absl-py[version='>=0.1.6|>=0.7.0|>=0.7.1,<1.0a0|>=0.7.1|>=0.8.1|>=0.10.0|>=0.11.0']
# tensorflow-estimator -> absl-py[version='>=0.1.6|>=0.7.0']
#
# Package setuptools conflicts for:
# sympy -> setuptools
# vincent -> setuptools
# plotly -> setuptools
# backports.functools_lru_cache -> setuptools
# matplotlib-base -> setuptools
# bleach -> setuptools
# joblib -> setuptools
# astropy -> setuptools
# protobuf -> setuptools
# google-auth -> setuptools[version='>=40.3.0']
# numexpr -> setuptools
# jsonschema -> setuptools
# pygments -> setuptools
# pytest -> setuptools[version='>=40.0']
# setuptools
# ibm-wsrt-py37main-main -> setuptools==47.3.1[build=*]
# tensorboard -> setuptools[version='>=41.0.0|>=41.4']
# jinja2 -> setuptools
# matplotlib -> setuptools
# wheel -> setuptools
# grpcio -> setuptools
# pip -> setuptools
# branca -> setuptools
# networkx -> setuptools
# markdown -> setuptools
# ipython -> setuptools[version='>=18.5']
#
# Package psycopg2 conflicts for:
# ibm-wsrt-py37main-keep -> psycopg2=[build=*]
# ibm-wsrt-py37main-main -> psycopg2==2.8.5[build=*]
# psycopg2
#
# Package pywavelets conflicts for:
# pywavelets
# scikit-image -> pywavelets[version='>=0.4.0']
# ibm-wsrt-py37main-main -> pywavelets==1.1.1[build=*]
#
# Package scikit-learn conflicts for:
# py-xgboost -> scikit-learn
# scikit-learn
# ibm-wsrt-py37main-keep -> scikit-learn=[build=*]
# ibm-wsrt-py37main-main -> scikit-learn==0.23.1[build=*]
# nltk -> scikit-learn
#
# Package kiwisolver conflicts for:
# matplotlib-base -> kiwisolver[version='>=1.0.1']
# kiwisolver
# matplotlib -> kiwisolver
# ibm-wsrt-py37main-main -> kiwisolver==1.2.0[build=*]
#
# Package scipy conflicts for:
# ibm-wsrt-py37main-main -> scipy==1.5.0[build=*]
# keras-preprocessing -> scipy[version='>=0.14']
# statsmodels -> scipy[version='>=0.14|>=1.0|>=1.2']
# scikit-learn -> scipy[version='>=0.19.1']
# seaborn-base -> scipy[version='>=1.0.1']
# pandas-profiling -> scipy[version='>=1.4.1']
# nltk -> scipy
# py-xgboost -> scipy
# tensorflow-base -> scipy[version='>=1.2.1|>=1.4.1|>=1.6.2|>=1.6.1']
# seaborn -> scipy[version='>=0.15.2|>=1.0.1']
# patsy -> scipy
# scikit-image -> scipy[version='>=0.17|>=0.19']
# astropy -> scipy[version='>=1.1']
# scipy
#
# Package libopenblas conflicts for:
# numexpr -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# scikit-learn -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.3,<1.0a0']
# numpy-base -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# numpy -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# scipy -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
#
# Package zlib conflicts for:
# libglib -> zlib[version='>=1.2.11,<1.3.0a0']
# pandoc -> zlib
# pytables -> zlib[version='>=1.2.11,<1.3.0a0']
# qt -> zlib[version='>=1.2.11,<1.3.0a0']
# python=3.7 -> zlib[version='>=1.2.11,<1.3.0a0']
# libllvm11 -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib -> zlib[version='>=1.2.11,<1.3.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0']
# libnghttp2 -> zlib[version='>=1.2.11,<1.3.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0']
# libcurl -> zlib[version='>=1.2.11,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# gst-plugins-base -> zlib[version='>=1.2.11,<1.3.0a0']
# cfitsio -> zlib[version='>=1.2.11,<1.3.0a0']
# blosc -> zlib[version='>=1.2.11,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0']
# nss -> zlib[version='>=1.2.11,<1.3.0a0']
# openjpeg -> zlib[version='>=1.2.11,<1.3.0a0']
# mysql-libs -> zlib[version='>=1.2.11,<1.3.0a0']
# glib -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0']
# grpcio -> zlib[version='>=1.2.11,<1.3.0a0']
# tensorflow-base -> zlib[version='>=1.2.11,<1.3.0a0']
# hdf5 -> zlib[version='1.2.*|>=1.2.11,<1.3.0a0']
# libprotobuf -> zlib[version='>=1.2.11,<1.3.0a0']
# ibm-wsrt-py37main-main -> zlib==1.2.11[build=*]
# imagecodecs -> zlib[version='>=1.2.11,<1.3.0a0']
# tk -> zlib[version='>=1.2.11,<1.3.0a0']
# zlib
# libssh2 -> zlib[version='>=1.2.11,<1.3.0a0']
# libpq -> zlib[version='>=1.2.11,<1.3.0a0']
#
# Package __glibc conflicts for:
# @/linux-64::__glibc==2.28=0
# @|@/linux-64::__glibc==2.28=0
# libgcc-ng -> __glibc[version='>=2.17']
# libstdcxx-ng -> __glibc[version='>=2.17']
# libgfortran-ng -> __glibc[version='>=2.17']
#
# Package blas conflicts for:
# mkl-service -> blas==1.0=mkl
# scipy -> blas[version='*|*|1.0|1.0',build='openblas|mkl|openblas|mkl']
# numpy -> blas[version='*|*|1.0|1.0',build='openblas|mkl|openblas|mkl']
# numpy-base -> blas[version='*|*|1.0|1.0',build='openblas|mkl|openblas|mkl']
# pytorch -> blas==1.0=mkl
# scikit-learn -> blas[version='*|*|1.0|1.0',build='openblas|mkl|openblas|mkl']
# blas
# mkl_fft -> blas[version='*|1.0',build=mkl]
# mkl_random -> blas[version='*|1.0',build=mkl]
# numexpr -> blas[version='*|*|1.0|1.0',build='openblas|mkl|openblas|mkl']
# ibm-wsrt-py37main-main -> blas==1.0[build=*]
#
# Package seaborn-base conflicts for:
# seaborn -> seaborn-base[version='>=0.11.1,<0.11.2.0a0']
# seaborn-base
#
# Package python-dateutil conflicts for:
# ibm-wsrt-py37main-main -> python-dateutil==2.8.1[build=*]
# pandas -> python-dateutil[version='>=2.5.*|>=2.6.1|>=2.7.3']
# matplotlib -> python-dateutil
# python-dateutil
# bokeh -> python-dateutil[version='>=2.1']
# matplotlib-base -> python-dateutil[version='>=2.1']
# jupyter_client -> python-dateutil[version='>=2.1']
# botocore -> python-dateutil[version='>=2.1,<2.7.0|>=2.1,<2.8.1|>=2.1,<3.0.0']
#
# Package jxrlib conflicts for:
# jxrlib
# imagecodecs -> jxrlib[version='>=1.1,<1.2.0a0']
#
# Package pandas conflicts for:
# pandas
# altair -> pandas
# ibm-wsrt-py37main-main -> pandas==1.0.5[build=*]
# seaborn-base -> pandas[version='>=0.23']
# pandas-profiling -> pandas[version='>=0.19|>=0.25.3,!=1.0.1,!=1.0.0,!=1.0.2,!=1.1.0']
# seaborn -> pandas[version='>=0.14.0|>=0.22.0']
# statsmodels -> pandas[version='>=0.14|>=0.21|>=0.23']
# arcgis=1.6.0 -> pandas[version='>=0.23']
# vincent -> pandas
# ibm-wsrt-py37main-keep -> pandas=[build=*]
# folium=0.5.0 -> pandas
# bokeh -> pandas
#
# Package jbig conflicts for:
# jbig
# libtiff -> jbig
#
# Package importlib_metadata conflicts for:
# pluggy -> importlib_metadata[version='>=0.12']
# importlib_metadata
# keyring -> importlib_metadata[version='>=1|>=3.6']
# jsonschema -> importlib_metadata
# ibm-wsrt-py37main-main -> importlib_metadata==1.6.1[build=*]
# pytest -> importlib_metadata[version='>=0.12']
# sqlalchemy -> importlib_metadata
#
# Package sqlite conflicts for:
# ibm-wsrt-py37main-main -> sqlite==3.33.0[build=*]
# python=3.7 -> sqlite[version='>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.4,<4.0a0']
# nss -> sqlite[version='>=3.31.1,<4.0a0|>=3.35.5,<4.0a0']
# qt -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.3,<4.0a0|>=3.34.0,<4.0a0']
# tensorflow-base -> sqlite[version='>=3.33.0,<4.0a0|>=3.35.4,<4.0a0']
# sqlite
#
# Package matplotlib conflicts for:
# astropy -> matplotlib[version='>=3.0']
# arcgis=1.6.0 -> matplotlib
# pandas-profiling -> matplotlib[version='>=1.4']
# ibm-wsrt-py37main-main -> matplotlib==3.2.2[build=*]
# seaborn -> matplotlib[version='>=1.4.3|>=2.1.2']
# nltk -> matplotlib
# ibm-wsrt-py37main-keep -> matplotlib=[build=*]
# scikit-image -> matplotlib[version='>=1.3.1|>=2.0.0']
# matplotlib
# bokeh -> matplotlib
#
# Package libpq conflicts for:
# qt -> libpq[version='>=13.1,<14.0a0']
# ibm-wsrt-py37main-main -> libpq==12.2[build=*]
# libpq
# psycopg2 -> libpq[version='>=10.3,<11.0a0|>=11.1,<12.0a0|>=11.2,<12.0a0|>=12.2,<13.0a0|>=9.6.6|>=13.3,<14.0a0']
#
# Package mkl_fft conflicts for:
# ibm-wsrt-py37main-main -> mkl_fft==1.1.0[build=*]
# mkl_fft
# numpy -> mkl_fft[version='>=1.0.4|>=1.0.6,<2.0a0|>=1.2.1,<2.0a0']
#
# Package nest-asyncio conflicts for:
# nbclient -> nest-asyncio
# nest-asyncio
#
# Package cudatoolkit conflicts for:
# tensorflow-base -> cudatoolkit[version='8.0.*|9.0.*|9.2.*|>=10.0.130,<10.1.0a0|>=10.1.243,<10.2.0a0|>=10.1.168,<10.2.0a0|>=9.2,<9.3.0a0|>=9.0,<9.1.0a0']
# pytorch -> cudatoolkit[version='10.0.*|>=10.0.130,<10.1.0a0|>=10.1.243,<10.2.0a0|>=9.2,<9.3.0a0|9.2.*|>=9.0,<9.1.0a0|>=8.0,<8.1.0a0|9.0.*|8.0.*|7.5.*']
# libxgboost -> cudatoolkit[version='8.0.*|>=10.0.130,<10.1.0a0|>=9.0,<9.1.0a0|>=9.2,<9.3.0a0|9.0.*|9.2.*']
# py-xgboost -> cudatoolkit[version='8.0.*|>=10.0.130,<10.1.0a0|>=9.0,<9.1.0a0|>=9.2,<9.3.0a0|9.0.*|9.2.*']
#
# Package astropy conflicts for:
# astropy
# ibm-wsrt-py37main-main -> astropy==4.0.1.post1[build=*]
# ibm-wsrt-py37main-keep -> astropy=[build=*]
#
# Package zstd conflicts for:
# imagecodecs -> zstd[version='>=1.4.4,<1.4.5.0a0|>=1.4.5,<1.4.6.0a0|>=1.5.0,<1.6.0a0|>=1.4.9,<1.5.0a0|>=1.4.5,<1.5.0a0|>=1.4.4,<1.5.0a0']
# mysql-libs -> zstd[version='>=1.5.0,<1.6.0a0']
# ibm-wsrt-py37main-main -> zstd==1.4.5[build=*]
# libtiff -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4|>=1.4.4,<1.4.5.0a0|>=1.5.0,<1.6.0a0|>=1.4.5,<1.5.0a0|>=1.4.4,<1.5.0a0']
# zstd
# blosc -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.4.5.0a0|>=1.4.5,<1.4.6.0a0|>=1.4.5,<1.5.0a0|>=1.4.4,<1.5.0a0']
#
# Package jupyterlab conflicts for:
# jupyterlab
# ibm-wsrt-py37main-main -> jupyterlab==2.2.6[build=*]
# arcgis=1.6.0 -> jupyterlab
# ibm-wsrt-py37main-keep -> jupyterlab==2.2.6[build=*]
#
# Package lcms2 conflicts for:
# imagecodecs -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# pillow -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# lcms2
# ibm-wsrt-py37main-main -> lcms2==2.11[build=*]
#
# Package pyyaml conflicts for:
# ibm-wsrt-py37main-main -> pyyaml==5.4.1[build=*]
# bokeh -> pyyaml[version='>=3.10']
# pyyaml
# dask-core -> pyyaml
# astropy -> pyyaml[version='>=3.13']
#
# Package mkl conflicts for:
# mkl_fft -> mkl[version='>=2018.0.3,<2019.0a0|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.3,<2020.0a0|>=2019.4,<2020.0a0|>=2020.4,<2021.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.3,<2021.0a0|>=2019.1,<2021.0a0']
# scipy -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.0|>=2018.0.2|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.4,<2020.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.2,<2019.0a0']
# numexpr -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.0|>=2018.0.1|>=2018.0.2|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.4,<2020.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.2,<2019.0a0|>=2018.0.1,<2019.0a0']
# numpy -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.0|>=2018.0.1|>=2018.0.2|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.3,<2020.0a0|>=2019.4,<2020.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.3,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.2,<2019.0a0|>=2018.0.1,<2019.0a0']
# tensorflow-base -> mkl[version='>=2018.0.2|>=2018.0.2,<2019.0a0']
# blas -> mkl
# numpy-base -> mkl[version='>=2018.0.2,<2019.0a0|>=2018.0.2|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.3,<2020.0a0|>=2019.4,<2020.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.3,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0']
# scikit-learn -> mkl[version='2018.*|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.3,<2020.0a0|>=2019.4,<2020.0a0|>=2018.0.0|>=2019.4,<2021.0a0|>=2019.3,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.0,<2019.0a0']
# mkl
# mkl_random -> mkl[version='>=2018.0.3,<2019.0a0|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.4,<2020.0a0|>=2020.1,<2021.0a0|>=2020.2,<2021.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.1,<2021.0a0']
# ibm-wsrt-py37main-main -> mkl==2020.1[build=*]
# mkl-service -> mkl[version='>=2018.0.0,<2019.0a0|>=2018.0.0|>=2018.0.3|>=2019.1,<2020.0a0|>=2019.3,<2020.0a0|>=2019.4,<2020.0a0|>=2020.2,<2021.0a0|>=2021.2.0,<2022.0a0|>=2019.4,<2021.0a0|>=2019.3,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0']
# libblas -> mkl[version='>=2020.4,<2021.0a0']
# pytorch -> mkl[version='2018.*|2019.*|>=2019.4,<2020.0a0|>=2019.1,<2020.0a0|>=2018.0.3|>=2018.0.2|>=2020.4,<2021.0a0|2020.*|>=2020.2,<2021.0a0|>=2019.4,<2021.0a0|>=2019.1,<2021.0a0|>=2018.0.3,<2019.0a0|>=2018.0.2,<2019.0a0']
#
# Package cx_oracle conflicts for:
# ibm-wsrt-py37main-keep -> cx_oracle=[build=*]
# ibm-wsrt-py37main-main -> cx_oracle==7.2.3[build=*]
# cx_oracle
#
# Package traitlets conflicts for:
# ibm-wsrt-py37main-main -> traitlets==4.3.3[build=*]
# ipykernel -> traitlets[version='>=4.1']
# traitlets
# notebook -> traitlets[version='>=4.2.1|>=4.3']
# jupyter_client -> traitlets
# ipython -> traitlets[version='>=4.2']
# nbclient -> traitlets[version='>=4.2']
# nbformat -> traitlets[version='>=4.1']
# nbconvert -> traitlets[version='>=4.2|>=5.0']
# jupyter_core -> traitlets
# ipywidgets -> traitlets[version='>=4.3.1|>=4.3.1,<5.0.0|>=4.3.1,<6.0.0']
# matplotlib-inline -> traitlets
#
# Package numpy-base conflicts for:
# ibm-wsrt-py37main-main -> numpy-base==1.18.5[build=*]
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0']
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0']
# ...
# libtiff -> jpeg[version='>=9b,<10a|>=9d,<10a']
#
# Package tensorboard conflicts for:
# ibm-wsrt-py37main-keep -> tensorboard=[build=*]
# ibm-wsrt-py37main-main -> tensorboard==2.1.0[build=*]
# tensorflow-base -> tensorboard[version='>=1.14.0,<1.15.0a0|>=2.5.0,<2.6']
# tensorboard
#
# Package sqlalchemy conflicts for:
# sqlalchemy
# ibm-wsrt-py37main-keep -> sqlalchemy=[build=*]
# ibm-wsrt-py37main-main -> sqlalchemy==1.3.17[build=*]
#
# Package lxml conflicts for:
# ibm-wsrt-py37main-main -> lxml==4.6.3[build=*]
# lxml
# ibm-wsrt-py37main-keep -> lxml=[build=*]
#
# Package s3transfer conflicts for:
# ibm-wsrt-py37main-main -> s3transfer==0.3.3[build=*]
# boto3 -> s3transfer[version='>=0.1.10,<0.2.0|>=0.2.0,<0.3.0|>=0.3.0,<0.4.0|>=0.4.0,<0.5.0']
# s3transfer
#
# Package jupyterlab_pygments conflicts for:
# jupyterlab_pygments
# nbconvert -> jupyterlab_pygments
#
# Package statsmodels conflicts for:
# ibm-wsrt-py37main-main -> statsmodels==0.11.1[build=*]
# statsmodels
# ibm-wsrt-py37main-keep -> statsmodels=[build=*]
# seaborn -> statsmodels[version='>=0.5.0|>=0.8.0']
#
# Package libzopfli conflicts for:
# imagecodecs -> libzopfli[version='>=1.0.3,<1.1.0a0']
# libzopfli
#
# Package blinker conflicts for:
# oauthlib -> blinker[version='>=1.4.0']
# blinker
# ibm-wsrt-py37main-main -> blinker==1.4[build=*]
#
# Package pysocks conflicts for:
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# ibm-wsrt-py37main-main -> pysocks==1.7.1[build=*]
# pysocks
#
# Package olefile conflicts for:
# olefile
# ibm-wsrt-py37main-main -> olefile==0.46[build=*]
# pillow -> olefile
#
# Package requests-oauthlib conflicts for:
# ibm-wsrt-py37main-main -> requests-oauthlib==1.3.0[build=*]
# requests-oauthlib
# google-auth-oauthlib -> requests-oauthlib[version='>=0.7.0']
#
# Package prompt-toolkit conflicts for:
# ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
# ibm-wsrt-py37main-main -> prompt-toolkit==3.0.5[build=*]
# prompt-toolkit
#
# Package gast conflicts for:
# tensorflow-base -> gast[version='0.4.0|>=0.2.0|>=0.2.2,<0.2.3.0a0|>=0.3.3,<0.3.4.0a0|>=0.4.0,<0.4.1.0a0']
# ibm-wsrt-py37main-main -> gast==0.2.2[build=*]
# tensorflow-estimator -> gast[version='>=0.2.0']
# gast
#
# Package liblapack conflicts for:
# numpy -> liblapack[version='>=3.8.0,<4.0a0']
# liblapack
# scipy -> liblapack[version='>=3.8.0,<4.0a0']
#
# Package tqdm conflicts for:
# pandas-profiling -> tqdm[version='>=4.43.0']
# nltk -> tqdm
# tqdm
# ibm-wsrt-py37main-main -> tqdm==4.47.0[build=*]
#
# Package beautifulsoup4 conflicts for:
# ibm-wsrt-py37main-keep -> beautifulsoup4=[build=*]
# beautifulsoup4
# soupsieve -> beautifulsoup4
# ibm-wsrt-py37main-main -> beautifulsoup4==4.9.1[build=*]
#
# Package jeepney conflicts for:
# jeepney
# keyring -> jeepney[version='>=0.4.2']
# ibm-wsrt-py37main-main -> jeepney==0.4.0[build=*]
# secretstorage -> jeepney[version='>=0.6']
#
# Package testpath conflicts for:
# testpath
# ibm-wsrt-py37main-main -> testpath==0.4.4[build=*]
# nbconvert -> testpath
#
# Package libedit conflicts for:
# ibm-wsrt-py37main-main -> libedit==3.1.20191231[build=*]
# sqlite -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# krb5 -> libedit[version='>=3.1,<4.0a0|>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20191231,<4.0a0|>=3.1.20181209,<4.0a0|>=3.1.20170329,<4.0a0']
# unixodbc -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# libedit
#
# Package readline conflicts for:
# python=3.7 -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0']
# libpq -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0']
# freetds -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0|>=8.1,<9.0a0']
# sqlite -> readline[version='>=8.0,<9.0a0|>=8.1,<9.0a0']
# ibm-wsrt-py37main-main -> readline==8.0[build=*]
# readline
#
# Package xorg-libxau conflicts for:
# xorg-libxau
# libxcb -> xorg-libxau
#
# Package ncurses conflicts for:
# ibm-wsrt-py37main-main -> ncurses==6.2[build=*]
# ncurses
# sqlite -> ncurses[version='>=6.2,<6.3.0a0|>=6.2,<7.0a0']
# libedit -> ncurses[version='6.0.*|>=6.1,<7.0a0|>=6.2,<7.0a0|>=6.2,<6.3.0a0']
# readline -> ncurses[version='6.0.*|>=6.0,<7.0a0|>=6.1,<7.0a0|>=6.2,<6.3.0a0|>=6.2,<7.0a0']
# python=3.7 -> ncurses[version='>=6.1,<7.0a0|>=6.2,<7.0a0|>=6.2,<6.3.0a0']
#
# Package pickleshare conflicts for:
# pickleshare
# ibm-wsrt-py37main-main -> pickleshare==0.7.5[build=*]
# ipython -> pickleshare
#
# Package mock conflicts for:
# tensorflow-base -> mock[version='>=2.0.0|>=2.0.0,<3.0a0']
# pytables -> mock
# mock
# ibm-wsrt-py37main-main -> mock==4.0.2[build=*]
# tensorflow-estimator -> mock[version='>=2.0.0']
#
# Package mistune conflicts for:
# nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# ibm-wsrt-py37main-main -> mistune==0.8.4[build=*]
# mistune
#
# Package markupsafe conflicts for:
# jinja2 -> markupsafe[version='>=0.23|>=2.0.0rc2|>=2.0']
# ibm-wsrt-py37main-main -> markupsafe==1.1.1[build=*]
# markupsafe
#
# Package openjpeg conflicts for:
# openjpeg
# imagecodecs -> openjpeg[version='>=2.3.0,<3.0a0|>=2.4.0,<2.5.0a0']
# pillow -> openjpeg[version='>=2.4.0,<2.5.0a0']
#
# Package singledispatch conflicts for:
# nltk -> singledispatch
# tornado -> singledispatch
#
# Package pandoc conflicts for:
# pandoc
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# ibm-wsrt-py37main-main -> pandoc==2.9.2.1[build=*]
#
# Package _libgcc_mutex conflicts for:
# _openmp_mutex -> _libgcc_mutex==0.1[build='main|conda_forge']
# libgcc-ng -> _libgcc_mutex[version='*|0.1',build='main|main|conda_forge']
# _libgcc_mutex
# ibm-wsrt-py37main-main -> _libgcc_mutex==0.1[build=*]
#
# Package hdf5 conflicts for:
# hdf5
# ibm-wsrt-py37main-main -> hdf5==1.10.4[build=*]
# h5py -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.20,<1.9.0a0|>=1.8.18,<1.8.19.0a0']
# pytables -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.8.20,<1.9.0a0|>=1.8.18,<1.8.19.0a0|>=1.10.6,<1.10.7.0a0']
#
# Package pyasn1 conflicts for:
# pyasn1-modules -> pyasn1[version='>=0.4.1,<0.5.0|>=0.4.6,<0.5.0']
# pyasn1
# ibm-wsrt-py37main-main -> pyasn1==0.4.8[build=*]
# rsa -> pyasn1[version='>=0.1.3']
#
# Package jmespath conflicts for:
# ibm-wsrt-py37main-main -> jmespath==0.9.4[build=*]
# botocore -> jmespath[version='>=0.7.1,<1.0.0']
# boto3 -> jmespath[version='>=0.7.1,<1.0.0']
# jmespath
#
# Package libglib conflicts for:
# glib-tools -> libglib==2.68.3=h3e27bee_0
# dbus -> libglib[version='>=2.68.0,<3.0a0']
# glib -> libglib==2.68.3=h3e27bee_0
# qt -> libglib[version='>=2.66.7,<3.0a0']
# libglib
# gst-plugins-base -> libglib[version='>=2.68.1,<3.0a0']
# gstreamer -> libglib[version='>=2.68.1,<3.0a0']
#
# Package zipp conflicts for:
# importlib_metadata -> zipp[version='>=0.3.2|>=0.5']
# importlib-metadata -> zipp[version='>=0.5']
# zipp
# ibm-wsrt-py37main-main -> zipp==3.1.0[build=*]
#
# Package mpfr conflicts for:
# mpfr
# gmpy2 -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0']
# mpc -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0']
#
# Package snowballstemmer conflicts for:
# ibm-wsrt-py37main-main -> snowballstemmer==2.0.0[build=*]
# snowballstemmer
# ibm-wsrt-py37main-keep -> snowballstemmer=[build=*]
#
# Package fastcache conflicts for:
# ibm-wsrt-py37main-main -> fastcache==1.1.0[build=*]
# fastcache
# sympy -> fastcache
#
# Package libxslt conflicts for:
# libxslt
# lxml -> libxslt[version='>=1.1.32,<2.0a0|>=1.1.33,<2.0a0|>=1.1.34,<2.0a0']
# ibm-wsrt-py37main-main -> libxslt==1.1.34[build=*]
#
# Package werkzeug conflicts for:
# ibm-wsrt-py37main-main -> werkzeug==1.0.1[build=*]
# tensorflow-base -> werkzeug[version='>=0.14.1,<1.0a0']
# werkzeug
# tensorboard -> werkzeug[version='>=0.11.10|>=0.11.15|>=0.14']
#
# Package partd conflicts for:
# dask-core -> partd[version='>=0.3.10']
# partd
#
# Package sip conflicts for:
# ibm-wsrt-py37main-main -> sip==4.19.8[build=*]
# sip
# pyqt -> sip[version='4.18.*|>=4.19.4|>=4.19.4,<=4.19.8|4.19.13.*|>=4.19.13,<=4.19.14']
#
# Package terminado conflicts for:
# terminado
# ibm-wsrt-py37main-main -> terminado==0.8.3[build=*]
# notebook -> terminado[version='>=0.3.3|>=0.8.1|>=0.8.3']
#
# Package zfp conflicts for:
# zfp
# imagecodecs -> zfp[version='>=0.5.5,<1.0a0']
#
# Package functools32 conflicts for:
# jsonschema -> functools32
# matplotlib -> functools32
# tensorflow-base -> functools32[version='>=3.2.3.2']
#
# Package c-ares conflicts for:
# c-ares
# ibm-wsrt-py37main-main -> c-ares==1.15.0[build=*]
# grpcio -> c-ares[version='>=1.15.0,<2.0a0|>=1.17.1,<2.0a0']
# libnghttp2 -> c-ares[version='>=1.16.1,<2.0a0|>=1.7.5|>=1.17.1,<2.0a0']
#
# Package imageio conflicts for:
# imageio
# ibm-wsrt-py37main-main -> imageio==2.9.0[build=*]
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0']
#
# Package libssh2 conflicts for:
# libssh2
# libcurl -> libssh2[version='>=1.8.0,<2.0a0|>=1.8.2,<2.0a0|>=1.9.0,<2.0a0']
#
# Package argon2-cffi conflicts for:
# argon2-cffi
# notebook -> argon2-cffi
#
# Package branca conflicts for:
# folium=0.5.0 -> branca
# branca
#
# Package yaml conflicts for:
# pyyaml -> yaml[version='>=0.1.7,<0.2.0a0|>=0.2.5,<0.3.0a0']
# yaml
# ibm-wsrt-py37main-main -> yaml==0.2.5[build=*]
#
# Package opt_einsum conflicts for:
# ibm-wsrt-py37main-main -> opt_einsum==3.1.0[build=*]
# opt_einsum
# tensorflow-base -> opt_einsum[version='3.3.0.*|>=2.3.2,<3.0a0|>=2.3.2|>=3.1.0|>=3.1.0,<4.0a0']
#
# Package pytest conflicts for:
# ibm-wsrt-py37main-keep -> pytest=[build=*]
# astropy -> pytest[version='<3.7|<4']
# ibm-wsrt-py37main-main -> pytest==5.4.3[build=*]
# pytest
#
# Package cycler conflicts for:
# matplotlib -> cycler[version='>=0.10']
# matplotlib-base -> cycler[version='>=0.10']
# ibm-wsrt-py37main-main -> cycler==0.10.0[build=*]
# cycler
#
# Package libllvm11 conflicts for:
# libclang -> libllvm11[version='>=11.1.0,<11.2.0a0']
# libllvm11
#
# Package altair conflicts for:
# altair
# folium=0.5.0 -> altair
#
# Package pyqt-impl conflicts for:
# pyqtchart -> pyqt-impl==5.12.3=py37he336c9b_7
# pyqt -> pyqt-impl==5.12.3=py37he336c9b_7
# pyqtwebengine -> pyqt-impl==5.12.3=py37he336c9b_7
# pyqt-impl
#
# Package libopus conflicts for:
# libopus
# gst-plugins-base -> libopus[version='>=1.3.1,<2.0a0']
#
# Package iniconfig conflicts for:
# pytest -> iniconfig
# iniconfig
#
# Package expat conflicts for:
# qt -> expat[version='>=2.2.10,<3.0.0a0|>=2.2.5,<3.0a0|>=2.2.6,<3.0a0']
# dbus -> expat[version='>=2.2.10,<3.0a0|>=2.2.6,<3.0a0|>=2.2.5,<3.0a0|>=2.3.0,<3.0.0a0']
# ibm-wsrt-py37main-main -> expat==2.2.9[build=*]
# expat
#
# Package vincent conflicts for:
# folium=0.5.0 -> vincent
# vincent
#
# Package geographiclib conflicts for:
# geographiclib
# geopy -> geographiclib[version='<2,>=1.49']
#
# Package appdirs conflicts for:
# pooch -> appdirs
# appdirs
#
# Package grpcio conflicts for:
# grpcio
# ibm-wsrt-py37main-main -> grpcio==1.27.2[build=*]
# tensorflow-estimator -> grpcio[version='>=1.8.6']
# tensorboard -> grpcio[version='>=1.14|>=1.24.3|>=1.6.3']
# tensorflow-base -> grpcio[version='>=1.14.1,<2.0a0|>=1.14.1|>=1.16.1|>=1.8.6|>=1.35.0']
#
# Package gmpy2 conflicts for:
# gmpy2
# sympy -> gmpy2[version='>=2.0.8']
#
# Package jsonschema conflicts for:
# nbformat -> jsonschema[version='>=2.4,!=2.5.0']
# jsonschema
# altair -> jsonschema
# jupyterlab_server -> jsonschema[version='>=3.0.1']
# ibm-wsrt-py37main-main -> jsonschema==3.2.0[build=*]
#
# Package greenlet conflicts for:
# sqlalchemy -> greenlet!=0.4.17
# greenlet
#
# Package pyodbc conflicts for:
# pyodbc
# ibm-wsrt-py37main-keep -> pyodbc=[build=*]
# ibm-wsrt-py37main-main -> pyodbc==4.0.30[build=*]
#
# Package funcsigs conflicts for:
# mock -> funcsigs
# pytest -> funcsigs[version='>=1.0']
#
# Package networkx conflicts for:
# networkx
# ibm-wsrt-py37main-main -> networkx==2.4[build=*]
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
#
# Package dask-core conflicts for:
# ibm-wsrt-py37main-main -> dask-core==2.20.0[build=*]
# scikit-image -> dask-core[version='>=0.15|>=0.15.0|>=0.9.0']
# dask-core
#
# Package glib conflicts for:
# gstreamer -> glib[version='>=2.53.6,<2.54.0a0|>=2.56.1,<2.57.0a0|>=2.66.1,<3.0a0|>=2.56.1,<3.0a0|>=2.53.6,<3.0a0']
# gst-plugins-base -> glib[version='>=2.53.6,<2.54.0a0|>=2.56.1,<2.57.0a0|>=2.66.1,<3.0a0|>=2.56.1,<3.0a0|>=2.53.6,<3.0a0']
# dbus -> glib[version='>=2.53.6,<2.54.0a0|>=2.56.1,<2.57.0a0|>=2.56.2,<2.57.0a0|>=2.63.1,<3.0a0|>=2.56.2,<3.0a0|>=2.56.1,<3.0a0|>=2.53.6,<3.0a0']
# qt -> glib[version='>=2.53.6,<2.54.0a0|>=2.56.1,<2.57.0a0|>=2.56.2,<2.57.0a0|>=2.56.2,<3.0a0|>=2.56.1,<3.0a0|>=2.53.6,<3.0a0']
# ibm-wsrt-py37main-main -> glib==2.65.0[build=*]
# glib
#
# Package rsa conflicts for:
# google-auth -> rsa[version='>=3.1.4,<4.1|>=3.1.4,<5']
# rsa
# ibm-wsrt-py37main-main -> rsa==4.6[build=*]
#
# Package plotly conflicts for:
# ibm-wsrt-py37main-main -> plotly==4.8.2[build=*]
# plotly
# ibm-wsrt-py37main-keep -> plotly=[build=*]
#
# Package pthread-stubs conflicts for:
# pthread-stubs
# libxcb -> pthread-stubs
#
# Package boto3 conflicts for:
# ibm-wsrt-py37main-main -> boto3==1.13.11[build=*]
# ibm-wsrt-py37main-keep -> boto3=[build=*]
# boto3
#
# Package _pytorch_select conflicts for:
# pytorch -> _pytorch_select[version='0.1|0.2']
# _pytorch_select
# ibm-wsrt-py37main-main -> _pytorch_select==0.1[build=*]
#
# Package jupyterlab_widgets conflicts for:
# ipywidgets -> jupyterlab_widgets[version='>=1.0.0']
# jupyterlab_widgets
#
# Package freetds conflicts for:
# ibm-wsrt-py37main-main -> freetds==1.00.97[build=*]
# freetds
# pymssql -> freetds[version='>=1.0.91,<2.0a0|>=1.0.97,<2.0a0']
#
# Package nltk conflicts for:
# nltk
# ibm-wsrt-py37main-main -> nltk==3.5.0[build=*]
# ibm-wsrt-py37main-keep -> nltk=[build=*]
#
# Package dill conflicts for:
# ibm-wsrt-py37main-keep -> dill=[build=*]
# dill
# ibm-wsrt-py37main-main -> dill==0.3.0[build=*]
#
# Package bzip2 conflicts for:
# imagecodecs -> bzip2[version='>=1.0.8,<2.0a0']
# bzip2
# cfitsio -> bzip2[version='>=1.0.8,<2.0a0']
# pytables -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ibm-wsrt-py37main-main -> bzip2==1.0.8[build=*]
#
# Package libevent conflicts for:
# qt -> libevent[version='>=2.1.10,<2.1.11.0a0']
# libevent
#
# Package libev conflicts for:
# libev
# libnghttp2 -> libev[version='>=4.11|>=4.33,<4.34.0a0']
#
# Package wcwidth conflicts for:
# ibm-wsrt-py37main-main -> wcwidth==0.2.4[build=*]
# pytest -> wcwidth
# prompt-toolkit -> wcwidth
# wcwidth
#
# Package fsspec conflicts for:
# dask-core -> fsspec[version='>=0.6.0']
# fsspec
#
# Package configparser conflicts for:
# importlib_metadata -> configparser[version='>=3.5']
# entrypoints -> configparser
#
# Package cfitsio conflicts for:
# cfitsio
# imagecodecs -> cfitsio[version='>=3.470,<3.471.0a0']
#
# Package gstreamer conflicts for:
# gstreamer
# ibm-wsrt-py37main-main -> gstreamer==1.14.0[build=*]
# qt -> gstreamer[version='>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0|>=1.18.3,<1.19.0a0']
# gst-plugins-base -> gstreamer[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.14.0,<2.0a0|>=1.18.4,<2.0a0']
#
# Package mpmath conflicts for:
# sympy -> mpmath[version='>=0.19']
# ibm-wsrt-py37main-main -> mpmath==1.1.0[build=*]
# mpmath
#
# Package async-timeout conflicts for:
# aiohttp -> async-timeout[version='<4.0,>=3.0|>=3.0,<4.0|>=1.2,<3.0|>=1.2.0']
# async-timeout
# ibm-wsrt-py37main-main -> async-timeout==3.0.1[build=*]
#
# Package xorg-libxdmcp conflicts for:
# libxcb -> xorg-libxdmcp
# xorg-libxdmcp
#
# Package pooch conflicts for:
# scikit-image -> pooch[version='>=1.3.0']
# pooch
#
# Package dataclasses conflicts for:
# dataclasses
# werkzeug -> dataclasses
#
# Package matplotlib-inline conflicts for:
# ipython -> matplotlib-inline[version='>=0.1.2']
# matplotlib-inline
#
# Package libxgboost conflicts for:
# ibm-wsrt-py37main-keep -> libxgboost=[build=*]
# ibm-wsrt-py37main-main -> libxgboost==0.90[build=*]
# libxgboost
# py-xgboost -> libxgboost[version='0.7|0.71|0.72|0.72|0.72|0.80|0.80|0.80|0.80|0.90|1.4.0|1.3.3',build='h9c3ff4c_0|h6cbba54_0|h6edc907_0|h51060c3_0|he6710b0_0|hf484d3e_1|he6710b0_1|h6edc907_0|h4d71fd4_0|h688424c_0|he6710b0_0|h87a4715_0|h83be7fe_0|hf484d3e_0|hf484d3e_0|hf484d3e_0|h2531618_0']
#
# Package libaec conflicts for:
# libaec
# imagecodecs -> libaec[version='>=1.0.4,<2.0a0|>=1.0.5,<2.0a0']
#
# Package pyu2f conflicts for:
# google-auth -> pyu2f[version='>=0.1.5']
# pyu2f
#
# Package nss conflicts for:
# qt -> nss[version='>=3.61,<4.0a0']
# nss
#
# Package threadpoolctl conflicts for:
# scikit-learn -> threadpoolctl[version='>=2.0.0']
# threadpoolctl
# ibm-wsrt-py37main-main -> threadpoolctl==2.1.0[build=*]
#
# Package libogg conflicts for:
# libogg
# libvorbis -> libogg[version='>=1.3.2,<2.0a0|>=1.3.4,<1.4.0a0']
# Note that strict channel priority may have removed packages required for satisfiability.
#
# Libraries imported.

# %%
# Define Foursquare Credentials and Version

CLIENT_ID = 'MMFCPN3VBOMV1YC0ISQPYNFSHQ4V5VUEPD24WHBMU55CEFKE' # your Foursquare ID
CLIENT_SECRET = '1MZKO5WUSU0WB4GH0PLR4URCOFA1B3MUGKXNZQONHDVZNPND' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude


def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return new_york_data

# %%
ny_data = get_new_york_data()
ny_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
ny_data.shape
# Out:
# (306, 4)

# %%
clr = "green"
ny_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Neighborhoods per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. Neighborhoods',fontsize = 15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %%
# queens has most neighborhoods
# prepare neighborhood list that contains japanese restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
italian_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in ny_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    italian_restaurants=venues[venues['Category']=='Italian Restaurant']   
    print('(',count,'/',len(ny_data),')','Italian Restaurants in '+Neighborhood+', '+Borough+':'+str(len(italian_restaurants)))
    print(row)
    for resturant_detail in italian_restaurants.values.tolist():
        id, name , category=resturant_detail
        italian_rest_ny = italian_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Italian Restaurants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) Italian Restaurants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) Italian Restaurants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) Italian Restaurants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) Italian Restaurants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) Italian Restaurants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) Italian Restaurants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) Italian Restaurants in Woodlawn, Bronx:1
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) Italian Restaurants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) Italian Restaurants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) Italian Restaurants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) Italian Restaurants in Pelham Parkway, Bronx:2
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) Italian Restaurants in City Island, Bronx:1
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) Italian Restaurants in Bedford Park, Bronx:1
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) Italian Restaurants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) Italian Restaurants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) Italian Restaurants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) Italian Restaurants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) Italian Restaurants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) Italian Restaurants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) Italian Restaurants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) Italian Restaurants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) Italian Restaurants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) Italian Restaurants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) Italian Restaurants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) Italian Restaurants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) Italian Restaurants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) Italian Restaurants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) Italian Restaurants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) Italian Restaurants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) Italian Restaurants in Parkchester, Bronx:0
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) Italian Restaurants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) Italian Restaurants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) Italian Restaurants in Morris Park, Bronx:1
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) Italian Restaurants in Belmont, Bronx:17
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) Italian Restaurants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) Italian Restaurants in North Riverdale, Bronx:1
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) Italian Restaurants in Pelham Bay, Bronx:2
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) Italian Restaurants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) Italian Restaurants in Edgewater Park, Bronx:1
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) Italian Restaurants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) Italian Restaurants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) Italian Restaurants in Pelham Gardens, Bronx:1
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) Italian Restaurants in Concourse, Bronx:1
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) Italian Restaurants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) Italian Restaurants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) Italian Restaurants in Bay Ridge, Brooklyn:5
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) Italian Restaurants in Bensonhurst, Brooklyn:2
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) Italian Restaurants in Sunset Park, Brooklyn:1
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) Italian Restaurants in Greenpoint, Brooklyn:0
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) Italian Restaurants in Gravesend, Brooklyn:1
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) Italian Restaurants in Brighton Beach, Brooklyn:0
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) Italian Restaurants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) Italian Restaurants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) Italian Restaurants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) Italian Restaurants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) Italian Restaurants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) Italian Restaurants in Kensington, Brooklyn:0
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) Italian Restaurants in Windsor Terrace, Brooklyn:0
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) Italian Restaurants in Prospect Heights, Brooklyn:0
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) Italian Restaurants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) Italian Restaurants in Williamsburg, Brooklyn:0
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) Italian Restaurants in Bushwick, Brooklyn:1
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) Italian Restaurants in Bedford Stuyvesant, Brooklyn:1
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) Italian Restaurants in Brooklyn Heights, Brooklyn:1
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) Italian Restaurants in Cobble Hill, Brooklyn:3
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) Italian Restaurants in Carroll Gardens, Brooklyn:8
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) Italian Restaurants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) Italian Restaurants in Gowanus, Brooklyn:0
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) Italian Restaurants in Fort Greene, Brooklyn:4
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 ) Italian Restaurants in Park Slope, Brooklyn:2
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 72 / 306 ) Italian Restaurants in Cypress Hills, Brooklyn:0
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 73 / 306 ) Italian Restaurants in East New York, Brooklyn:0
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 74 / 306 ) Italian Restaurants in Starrett City, Brooklyn:0
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 75 / 306 ) Italian Restaurants in Canarsie, Brooklyn:0
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 76 / 306 ) Italian Restaurants in Flatlands, Brooklyn:0
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 77 / 306 ) Italian Restaurants in Mill Island, Brooklyn:0
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 78 / 306 ) Italian Restaurants in Manhattan Beach, Brooklyn:0
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 79 / 306 ) Italian Restaurants in Coney Island, Brooklyn:0
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 80 / 306 ) Italian Restaurants in Bath Beach, Brooklyn:2
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 81 / 306 ) Italian Restaurants in Borough Park, Brooklyn:0
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 82 / 306 ) Italian Restaurants in Dyker Heights, Brooklyn:1
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 83 / 306 ) Italian Restaurants in Gerritsen Beach, Brooklyn:0
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 84 / 306 ) Italian Restaurants in Marine Park, Brooklyn:0
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 85 / 306 ) Italian Restaurants in Clinton Hill, Brooklyn:3
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 86 / 306 ) Italian Restaurants in Sea Gate, Brooklyn:0
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 87 / 306 ) Italian Restaurants in Downtown, Brooklyn:0
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 88 / 306 ) Italian Restaurants in Boerum Hill, Brooklyn:1
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 89 / 306 ) Italian Restaurants in Prospect Lefferts Gardens, Brooklyn:1
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 90 / 306 ) Italian Restaurants in Ocean Hill, Brooklyn:0
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 91 / 306 ) Italian Restaurants in City Line, Brooklyn:0
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 92 / 306 ) Italian Restaurants in Bergen Beach, Brooklyn:0
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 93 / 306 ) Italian Restaurants in Midwood, Brooklyn:0
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 94 / 306 ) Italian Restaurants in Prospect Park South, Brooklyn:0
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 95 / 306 ) Italian Restaurants in Georgetown, Brooklyn:0
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 96 / 306 ) Italian Restaurants in East Williamsburg, Brooklyn:0
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 97 / 306 ) Italian Restaurants in North Side, Brooklyn:1
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 98 / 306 ) Italian Restaurants in South Side, Brooklyn:1
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 99 / 306 ) Italian Restaurants in Ocean Parkway, Brooklyn:0
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 100 / 306 ) Italian Restaurants in Fort Hamilton, Brooklyn:3
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 101 / 306 ) Italian Restaurants in Chinatown, Manhattan:1
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 102 / 306 ) Italian Restaurants in Washington Heights, Manhattan:1
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 103 / 306 ) Italian Restaurants in Inwood, Manhattan:1
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 104 / 306 ) Italian Restaurants in Hamilton Heights, Manhattan:1
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 105 / 306 ) Italian Restaurants in Manhattanville, Manhattan:1
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 106 / 306 ) Italian Restaurants in Central Harlem, Manhattan:0
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 107 / 306 ) Italian Restaurants in East Harlem, Manhattan:0
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 108 / 306 ) Italian Restaurants in Upper East Side, Manhattan:5
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 109 / 306 ) Italian Restaurants in Yorkville, Manhattan:7
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 110 / 306 ) Italian Restaurants in Lenox Hill, Manhattan:8
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 111 / 306 ) Italian Restaurants in Roosevelt Island, Manhattan:0
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 112 / 306 ) Italian Restaurants in Upper West Side, Manhattan:3
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 113 / 306 ) Italian Restaurants in Lincoln Square, Manhattan:2
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 114 / 306 ) Italian Restaurants in Clinton, Manhattan:4
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 115 / 306 ) Italian Restaurants in Midtown, Manhattan:2
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 116 / 306 ) Italian Restaurants in Murray Hill, Manhattan:1
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 117 / 306 ) Italian Restaurants in Chelsea, Manhattan:3
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 118 / 306 ) Italian Restaurants in Greenwich Village, Manhattan:16
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 119 / 306 ) Italian Restaurants in East Village, Manhattan:2
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 120 / 306 ) Italian Restaurants in Lower East Side, Manhattan:0
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 121 / 306 ) Italian Restaurants in Tribeca, Manhattan:1
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 122 / 306 ) Italian Restaurants in Little Italy, Manhattan:2
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 123 / 306 ) Italian Restaurants in Soho, Manhattan:6
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 124 / 306 ) Italian Restaurants in West Village, Manhattan:10
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 125 / 306 ) Italian Restaurants in Manhattan Valley, Manhattan:1
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 126 / 306 ) Italian Restaurants in Morningside Heights, Manhattan:0
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 127 / 306 ) Italian Restaurants in Gramercy, Manhattan:3
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 128 / 306 ) Italian Restaurants in Battery Park City, Manhattan:2
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 129 / 306 ) Italian Restaurants in Financial District, Manhattan:4
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 130 / 306 ) Italian Restaurants in Astoria, Queens:0
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 131 / 306 ) Italian Restaurants in Woodside, Queens:0
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 132 / 306 ) Italian Restaurants in Jackson Heights, Queens:0
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 133 / 306 ) Italian Restaurants in Elmhurst, Queens:0
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 134 / 306 ) Italian Restaurants in Howard Beach, Queens:3
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 135 / 306 ) Italian Restaurants in Corona, Queens:1
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 136 / 306 ) Italian Restaurants in Forest Hills, Queens:0
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 137 / 306 ) Italian Restaurants in Kew Gardens, Queens:0
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 138 / 306 ) Italian Restaurants in Richmond Hill, Queens:0
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 139 / 306 ) Italian Restaurants in Flushing, Queens:1
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 140 / 306 ) Italian Restaurants in Long Island City, Queens:1
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 141 / 306 ) Italian Restaurants in Sunnyside, Queens:0
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 142 / 306 ) Italian Restaurants in East Elmhurst, Queens:0
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 143 / 306 ) Italian Restaurants in Maspeth, Queens:1
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 144 / 306 ) Italian Restaurants in Ridgewood, Queens:2
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 145 / 306 ) Italian Restaurants in Glendale, Queens:0
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 146 / 306 ) Italian Restaurants in Rego Park, Queens:1
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 147 / 306 ) Italian Restaurants in Woodhaven, Queens:0
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 148 / 306 ) Italian Restaurants in Ozone Park, Queens:0
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 149 / 306 ) Italian Restaurants in South Ozone Park, Queens:0
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 150 / 306 ) Italian Restaurants in College Point, Queens:0
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 151 / 306 ) Italian Restaurants in Whitestone, Queens:0
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 152 / 306 ) Italian Restaurants in Bayside, Queens:2
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 153 / 306 ) Italian Restaurants in Auburndale, Queens:1
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 154 / 306 ) Italian Restaurants in Little Neck, Queens:2
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 155 / 306 ) Italian Restaurants in Douglaston, Queens:1
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 156 / 306 ) Italian Restaurants in Glen Oaks, Queens:0
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 157 / 306 ) Italian Restaurants in Bellerose, Queens:0
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 158 / 306 ) Italian Restaurants in Kew Gardens Hills, Queens:0
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 159 / 306 ) Italian Restaurants in Fresh Meadows, Queens:0
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 160 / 306 ) Italian Restaurants in Briarwood, Queens:0
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 161 / 306 ) Italian Restaurants in Jamaica Center, Queens:0
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 162 / 306 ) Italian Restaurants in Oakland Gardens, Queens:0
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 163 / 306 ) Italian Restaurants in Queens Village, Queens:0
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 164 / 306 ) Italian Restaurants in Hollis, Queens:0
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 165 / 306 ) Italian Restaurants in South Jamaica, Queens:0
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 166 / 306 ) Italian Restaurants in St. Albans, Queens:0
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 167 / 306 ) Italian Restaurants in Rochdale, Queens:0
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 168 / 306 ) Italian Restaurants in Springfield Gardens, Queens:0
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 169 / 306 ) Italian Restaurants in Cambria Heights, Queens:0
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 170 / 306 ) Italian Restaurants in Rosedale, Queens:0
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 171 / 306 ) Italian Restaurants in Far Rockaway, Queens:0
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 172 / 306 ) Italian Restaurants in Broad Channel, Queens:0
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 173 / 306 ) Italian Restaurants in Breezy Point, Queens:0
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 174 / 306 ) Italian Restaurants in Steinway, Queens:0
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 175 / 306 ) Italian Restaurants in Beechhurst, Queens:0
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 176 / 306 ) Italian Restaurants in Bay Terrace, Queens:0
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 177 / 306 ) Italian Restaurants in Edgemere, Queens:0
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 178 / 306 ) Italian Restaurants in Arverne, Queens:0
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 179 / 306 ) Italian Restaurants in Rockaway Beach, Queens:0
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 180 / 306 ) Italian Restaurants in Neponsit, Queens:0
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 181 / 306 ) Italian Restaurants in Murray Hill, Queens:0
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 182 / 306 ) Italian Restaurants in Floral Park, Queens:0
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 183 / 306 ) Italian Restaurants in Holliswood, Queens:0
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 184 / 306 ) Italian Restaurants in Jamaica Estates, Queens:0
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 185 / 306 ) Italian Restaurants in Queensboro Hill, Queens:0
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 186 / 306 ) Italian Restaurants in Hillcrest, Queens:0
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 187 / 306 ) Italian Restaurants in Ravenswood, Queens:1
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 188 / 306 ) Italian Restaurants in Lindenwood, Queens:0
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 189 / 306 ) Italian Restaurants in Laurelton, Queens:0
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 190 / 306 ) Italian Restaurants in Lefrak City, Queens:0
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 191 / 306 ) Italian Restaurants in Belle Harbor, Queens:0
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 192 / 306 ) Italian Restaurants in Rockaway Park, Queens:0
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 193 / 306 ) Italian Restaurants in Somerville, Queens:0
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 194 / 306 ) Italian Restaurants in Brookville, Queens:0
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 195 / 306 ) Italian Restaurants in Bellaire, Queens:0
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 196 / 306 ) Italian Restaurants in North Corona, Queens:0
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 197 / 306 ) Italian Restaurants in Forest Hills Gardens, Queens:0
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 198 / 306 ) Italian Restaurants in St. George, Staten Island:2
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 199 / 306 ) Italian Restaurants in New Brighton, Staten Island:0
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 200 / 306 ) Italian Restaurants in Stapleton, Staten Island:0
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 201 / 306 ) Italian Restaurants in Rosebank, Staten Island:1
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 202 / 306 ) Italian Restaurants in West Brighton, Staten Island:2
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 203 / 306 ) Italian Restaurants in Grymes Hill, Staten Island:0
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 204 / 306 ) Italian Restaurants in Todt Hill, Staten Island:0
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 205 / 306 ) Italian Restaurants in South Beach, Staten Island:0
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 206 / 306 ) Italian Restaurants in Port Richmond, Staten Island:0
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 207 / 306 ) Italian Restaurants in Mariner's Harbor, Staten Island:1
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 208 / 306 ) Italian Restaurants in Port Ivory, Staten Island:0
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 209 / 306 ) Italian Restaurants in Castleton Corners, Staten Island:0
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ( 210 / 306 ) Italian Restaurants in New Springville, Staten Island:0
# ['Staten Island', 'New Springville', 40.594252379161695, -74.16496031329827]
# ( 211 / 306 ) Italian Restaurants in Travis, Staten Island:0
# ['Staten Island', 'Travis', 40.58631375103281, -74.19073717538116]
# ( 212 / 306 ) Italian Restaurants in New Dorp, Staten Island:3
# ['Staten Island', 'New Dorp', 40.57257231820632, -74.1164794360638]
# ( 213 / 306 ) Italian Restaurants in Oakwood, Staten Island:0
# ['Staten Island', 'Oakwood', 40.5584622432888, -74.12156593771896]
# ( 214 / 306 ) Italian Restaurants in Great Kills, Staten Island:2
# ['Staten Island', 'Great Kills', 40.549480228713605, -74.14932381490992]
# ( 215 / 306 ) Italian Restaurants in Eltingville, Staten Island:3
# ['Staten Island', 'Eltingville', 40.542230747450745, -74.1643308041936]
# ( 216 / 306 ) Italian Restaurants in Annadale, Staten Island:0
# ['Staten Island', 'Annadale', 40.53811417474507, -74.17854866165878]
# ( 217 / 306 ) Italian Restaurants in Woodrow, Staten Island:1
# ['Staten Island', 'Woodrow', 40.541967622888755, -74.20524582480326]
# ( 218 / 306 ) Italian Restaurants in Tottenville, Staten Island:0
# ['Staten Island', 'Tottenville', 40.50533376115642, -74.24656934235283]
# ( 219 / 306 ) Italian Restaurants in Tompkinsville, Staten Island:0
# ['Staten Island', 'Tompkinsville', 40.637316067110326, -74.08055351790115]
# ( 220 / 306 ) Italian Restaurants in Silver Lake, Staten Island:0
# ['Staten Island', 'Silver Lake', 40.61919310792676, -74.09629029235458]
# ( 221 / 306 ) Italian Restaurants in Sunnyside, Staten Island:0
# ['Staten Island', 'Sunnyside', 40.61276015756489, -74.0971255217853]
# ( 222 / 306 ) Italian Restaurants in Ditmas Park, Brooklyn:0
# ['Brooklyn', 'Ditmas Park', 40.643675183340974, -73.96101312466779]
# ( 223 / 306 ) Italian Restaurants in Wingate, Brooklyn:0
# ['Brooklyn', 'Wingate', 40.66094656188111, -73.93718680559314]
# ( 224 / 306 ) Italian Restaurants in Rugby, Brooklyn:0
# ['Brooklyn', 'Rugby', 40.655572313280764, -73.92688212616955]
# ( 225 / 306 ) Italian Restaurants in Park Hill, Staten Island:0
# ['Staten Island', 'Park Hill', 40.60919044434558, -74.08015734936296]
# ( 226 / 306 ) Italian Restaurants in Westerleigh, Staten Island:0
# ['Staten Island', 'Westerleigh', 40.62109047275409, -74.13304143951704]
# ( 227 / 306 ) Italian Restaurants in Graniteville, Staten Island:0
# ['Staten Island', 'Graniteville', 40.620171512231884, -74.15315246387762]
# ( 228 / 306 ) Italian Restaurants in Arlington, Staten Island:0
# ['Staten Island', 'Arlington', 40.63532509911492, -74.16510420241124]
# ( 229 / 306 ) Italian Restaurants in Arrochar, Staten Island:2
# ['Staten Island', 'Arrochar', 40.596312571276734, -74.06712363225574]
# ( 230 / 306 ) Italian Restaurants in Grasmere, Staten Island:1
# ['Staten Island', 'Grasmere', 40.59826835959991, -74.0766743627905]
# ( 231 / 306 ) Italian Restaurants in Old Town, Staten Island:3
# ['Staten Island', 'Old Town', 40.59632891379513, -74.08751118005578]
# ( 232 / 306 ) Italian Restaurants in Dongan Hills, Staten Island:0
# ['Staten Island', 'Dongan Hills', 40.588672948199275, -74.09639905312521]
# ( 233 / 306 ) Italian Restaurants in Midland Beach, Staten Island:0
# ['Staten Island', 'Midland Beach', 40.57352690574283, -74.09348266303591]
# ( 234 / 306 ) Italian Restaurants in Grant City, Staten Island:0
# ['Staten Island', 'Grant City', 40.57621558711788, -74.10585598545434]
# ( 235 / 306 ) Italian Restaurants in New Dorp Beach, Staten Island:2
# ['Staten Island', 'New Dorp Beach', 40.56425549307335, -74.10432707469124]
# ( 236 / 306 ) Italian Restaurants in Bay Terrace, Staten Island:1
# ['Staten Island', 'Bay Terrace', 40.55398800858462, -74.13916622175768]
# ( 237 / 306 ) Italian Restaurants in Huguenot, Staten Island:1
# ['Staten Island', 'Huguenot', 40.531911920489605, -74.19174105747814]
# ( 238 / 306 ) Italian Restaurants in Pleasant Plains, Staten Island:0
# ['Staten Island', 'Pleasant Plains', 40.524699376118136, -74.21983106616777]
# ( 239 / 306 ) Italian Restaurants in Butler Manor, Staten Island:0
# ['Staten Island', 'Butler Manor', 40.50608165346305, -74.22950350260027]
# ( 240 / 306 ) Italian Restaurants in Charleston, Staten Island:0
# ['Staten Island', 'Charleston', 40.53053148283314, -74.23215775896526]
# ( 241 / 306 ) Italian Restaurants in Rossville, Staten Island:0
# ['Staten Island', 'Rossville', 40.54940400650072, -74.21572851113952]
# ( 242 / 306 ) Italian Restaurants in Arden Heights, Staten Island:0
# ['Staten Island', 'Arden Heights', 40.54928582278321, -74.18588674583893]
# ( 243 / 306 ) Italian Restaurants in Greenridge, Staten Island:0
# ['Staten Island', 'Greenridge', 40.555295236173194, -74.17079414786092]
# ( 244 / 306 ) Italian Restaurants in Heartland Village, Staten Island:0
# ['Staten Island', 'Heartland Village', 40.58913894875281, -74.15902208156601]
# ( 245 / 306 ) Italian Restaurants in Chelsea, Staten Island:1
# ['Staten Island', 'Chelsea', 40.59472602746295, -74.1895604551969]
# ( 246 / 306 ) Italian Restaurants in Bloomfield, Staten Island:0
# ['Staten Island', 'Bloomfield', 40.60577868452358, -74.18725638381567]
# ( 247 / 306 ) Italian Restaurants in Bulls Head, Staten Island:0
# ['Staten Island', 'Bulls Head', 40.6095918004203, -74.15940948657122]
# ( 248 / 306 ) Italian Restaurants in Carnegie Hill, Manhattan:1
# ['Manhattan', 'Carnegie Hill', 40.7826825671257, -73.95325646837112]
# ( 249 / 306 ) Italian Restaurants in Noho, Manhattan:6
# ['Manhattan', 'Noho', 40.72325901885768, -73.98843368023597]
# ( 250 / 306 ) Italian Restaurants in Civic Center, Manhattan:3
# ['Manhattan', 'Civic Center', 40.71522892046282, -74.00541529873355]
# ( 251 / 306 ) Italian Restaurants in Midtown South, Manhattan:2
# ['Manhattan', 'Midtown South', 40.7485096643122, -73.98871313285247]
# ( 252 / 306 ) Italian Restaurants in Richmond Town, Staten Island:0
# ['Staten Island', 'Richmond Town', 40.56960594275505, -74.1340572986257]
# ( 253 / 306 ) Italian Restaurants in Shore Acres, Staten Island:2
# ['Staten Island', 'Shore Acres', 40.60971934079284, -74.06667766061771]
# ( 254 / 306 ) Italian Restaurants in Clifton, Staten Island:0
# ['Staten Island', 'Clifton', 40.61917845202843, -74.072642445484]
# ( 255 / 306 ) Italian Restaurants in Concord, Staten Island:0
# ['Staten Island', 'Concord', 40.6044731896879, -74.08402364740358]
# ( 256 / 306 ) Italian Restaurants in Emerson Hill, Staten Island:0
# ['Staten Island', 'Emerson Hill', 40.606794394801, -74.09776206972522]
# ( 257 / 306 ) Italian Restaurants in Randall Manor, Staten Island:0
# ['Staten Island', 'Randall Manor', 40.63563000681151, -74.09805062373887]
# ( 258 / 306 ) Italian Restaurants in Howland Hook, Staten Island:0
# ['Staten Island', 'Howland Hook', 40.63843283794795, -74.18622331749823]
# ( 259 / 306 ) Italian Restaurants in Elm Park, Staten Island:0
# ['Staten Island', 'Elm Park', 40.630146741193826, -74.1418167896889]
# ( 260 / 306 ) Italian Restaurants in Remsen Village, Brooklyn:0
# ['Brooklyn', 'Remsen Village', 40.652117451793494, -73.91665331978048]
# ( 261 / 306 ) Italian Restaurants in New Lots, Brooklyn:0
# ['Brooklyn', 'New Lots', 40.6627442796966, -73.88511776379292]
# ( 262 / 306 ) Italian Restaurants in Paerdegat Basin, Brooklyn:0
# ['Brooklyn', 'Paerdegat Basin', 40.63131755039667, -73.90233474295836]
# ( 263 / 306 ) Italian Restaurants in Mill Basin, Brooklyn:0
# ['Brooklyn', 'Mill Basin', 40.61597423962336, -73.91515391550404]
# ( 264 / 306 ) Italian Restaurants in Jamaica Hills, Queens:0
# ['Queens', 'Jamaica Hills', 40.71145964370482, -73.79646462081593]
# ( 265 / 306 ) Italian Restaurants in Utopia, Queens:0
# ['Queens', 'Utopia', 40.73350025429757, -73.79671678028349]
# ( 266 / 306 ) Italian Restaurants in Pomonok, Queens:0
# ['Queens', 'Pomonok', 40.73493618075478, -73.80486120040537]
# ( 267 / 306 ) Italian Restaurants in Astoria Heights, Queens:1
# ['Queens', 'Astoria Heights', 40.7703173929982, -73.89467996270574]
# ( 268 / 306 ) Italian Restaurants in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 269 / 306 ) Italian Restaurants in Concourse Village, Bronx:1
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 270 / 306 ) Italian Restaurants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 271 / 306 ) Italian Restaurants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 272 / 306 ) Italian Restaurants in Sutton Place, Manhattan:4
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 273 / 306 ) Italian Restaurants in Hunters Point, Queens:3
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 274 / 306 ) Italian Restaurants in Turtle Bay, Manhattan:3
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 275 / 306 ) Italian Restaurants in Tudor City, Manhattan:0
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 276 / 306 ) Italian Restaurants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 277 / 306 ) Italian Restaurants in Flatiron, Manhattan:5
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 278 / 306 ) Italian Restaurants in Sunnyside Gardens, Queens:0
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 279 / 306 ) Italian Restaurants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 280 / 306 ) Italian Restaurants in Fulton Ferry, Brooklyn:1
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 281 / 306 ) Italian Restaurants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 282 / 306 ) Italian Restaurants in Weeksville, Brooklyn:0
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 283 / 306 ) Italian Restaurants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 284 / 306 ) Italian Restaurants in Dumbo, Brooklyn:1
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 285 / 306 ) Italian Restaurants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 286 / 306 ) Italian Restaurants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 287 / 306 ) Italian Restaurants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 288 / 306 ) Italian Restaurants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 289 / 306 ) Italian Restaurants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 290 / 306 ) Italian Restaurants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 291 / 306 ) Italian Restaurants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 292 / 306 ) Italian Restaurants in Prince's Bay, Staten Island:1
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 293 / 306 ) Italian Restaurants in Lighthouse Hill, Staten Island:1
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 294 / 306 ) Italian Restaurants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 295 / 306 ) Italian Restaurants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 296 / 306 ) Italian Restaurants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 297 / 306 ) Italian Restaurants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 298 / 306 ) Italian Restaurants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 299 / 306 ) Italian Restaurants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 300 / 306 ) Italian Restaurants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 301 / 306 ) Italian Restaurants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 302 / 306 ) Italian Restaurants in Hudson Yards, Manhattan:0
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 303 / 306 ) Italian Restaurants in Hammels, Queens:0
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 304 / 306 ) Italian Restaurants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 305 / 306 ) Italian Restaurants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 306 / 306 ) Italian Restaurants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %%
italian_rest_ny.to_csv('italian_rest_ny_tocsv1.csv')

# %%
italian_ny = pd.read_csv('italian_rest_ny_tocsv1.csv')
italian_rest_ny.tail()
# Out:
#            Borough     Neighborhood                        ID  \
# 231      Manhattan         Flatiron  53370455498e18d7e6607a1d
# 232       Brooklyn     Fulton Ferry  593c0d2262420b7feccc3048
# 233       Brooklyn            Dumbo  593c0d2262420b7feccc3048
# 234  Staten Island     Prince's Bay  4c091311a1b32d7f5efb96f0
# 235  Staten Island  Lighthouse Hill  5079ccdce4b065f1dd8155ad
#
#                                  Name
# 231               La Pizza & La Pasta
# 232                         Cecconi's
# 233                         Cecconi's
# 234  Certo's Gourmet Foods & Caterers
# 235                        Casa verde

# %%
italian_rest_ny.shape
# Out:
# (236, 4)

# %%
italian_rest_ny.groupby('Borough')['ID'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Italian Restaurants per Borough: NYC', fontsize = 20)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No. of Italian Restaurants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %%
NOofNeigh = 6 # top number for graphing all the same past 6
italian_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(NOofNeigh).plot.bar(figsize=(10,5), color=clr)
plt.title('Italian Restaurants per Neighborhood: NYC', fontsize = 20)
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('No. of Italian Restaurants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %%
italian_rest_ny[italian_rest_ny['Neighborhood']=='Belmont']
# Out:
#    Borough Neighborhood                        ID  \
# 6    Bronx      Belmont  4acf80aef964a52025d420e3
# 7    Bronx      Belmont  59050f51b23dfa5f6649e678
# 8    Bronx      Belmont  4af71916f964a520cf0522e3
# 9    Bronx      Belmont  4bb6470cef159c7465b275f7
# 10   Bronx      Belmont  4b5514c4f964a5207cda27e3
# 11   Bronx      Belmont  4b5a4c8ff964a52049bb28e3
# 12   Bronx      Belmont  4af0fa29f964a52060e021e3
# 13   Bronx      Belmont  4c9b9e7b9c663704b90463fd
# 14   Bronx      Belmont  4aa193d5f964a520124120e3
# 15   Bronx      Belmont  4aa425bef964a5208e4520e3
# 16   Bronx      Belmont  4cb0d382ef1b370419643e00
# 17   Bronx      Belmont  4bc22a22920eb713bcc51b2c
# 18   Bronx      Belmont  4b5bc595f964a520431529e3
# 19   Bronx      Belmont  4bc67f1104e8b713a833362d
# 20   Bronx      Belmont  53ff939c498e6b601dfa3979
# 21   Bronx      Belmont  44941e38f964a52081341fe3
# 22   Bronx      Belmont  4c79d294278eb713f6a05580
#
#                                                  Name
# 6                                 Tino's Delicatessen
# 7                                Arthur Avenue Fiasco
# 8   Michaelangelo's Coal Fired Brick Oven Pizza Re...
# 9                                 Calabria Pork Store
# 10                                             Enzo's
# 11                                Emilia's Restaurant
# 12                                Antonio's Trattoria
# 13                                 Gerbasi Ristorante
# 14                      Mario's Restaurant & Catering
# 15                              Dominick's Restaurant
# 16              David Greco's Arthur Avenue Trattoria
# 17                                         Tra Di Noi
# 18                              Pasquale Riggaletto's
# 19  Ann & Tony's - An Original Arthur Avenue Resta...
# 20                             San Gennaro Ristorante
# 21                                 Arthur Avenue Cafe
# 22                                    Cafe al Mercato

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
italian_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1
for row in italian_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except (IndexError):
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(italian_rest_ny),')','processed')
    italian_rest_stats_ny = italian_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
italian_rest_stats_ny.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '60df0dd3890aaa10913995c2'}, 'response': {'venue': {'id': '511edb6de4b0d58346fd272d', 'name': "Patrizia's Of Woodlawn", 'contact': {'phone': '7188845700', 'formattedPhone': '(718) 884-5700'}, 'location': {'address': '4358 Katonah Ave', 'lat': 40.900638399332884, 'lng': -73.86772361835486, 'labeledLatLngs': [{'label': 'display', 'lat': 40.900638399332884, 'lng': -73.86772361835486}, {'label': 'entrance', 'lat': 40.900601, 'lng': -73.867611}], 'postalCode': '10470', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['4358 Katonah Ave', 'Bronx, NY 10470', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/patrizias-of-woodlawn/511edb6de4b0d58346fd272d', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 14}, 'url': 'http://patriziaspizza.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 18, 'groups': [{'type': 'others', 'count': 18, 'items': []}], 'summary': '18 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 18, 'delivery': {'id': '277050', 'url': 'https://www.seamless.com/menu/patrizias-of-woodlawn-4358-katonah-ave-bronx/277050?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=277050', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://patriziaspizza.com/restaurants/ny/bronx/10470/patrizia-s-of-woodlawn/menu/', 'mobileUrl': 'http://patriziaspizza.com/restaurants/ny/bronx/10470/patrizia-s-of-woodlawn/menu/', 'externalUrl': 'http://patriziaspizza.com/restaurants/ny/bronx/10470/patrizia-s-of-woodlawn/menu/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '532e0a61498eed2c785dd473', 'createdAt': 1395526241, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/5383181_SOrG_qTDBC4leb-IKQkMZ4neyLGcYb6kv-TKoaclgfo.jpg', 'width': 960, 'height': 720, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1360976749, 'tips': {'count': 14, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 14, 'items': [{'id': '5224c1da11d2bcafc67dfb44', 'createdAt': 1378140634, 'text': "Coconut shrimp was great! Ravioli with vodka sauce was really good. Chicken parm was okay. They're almond cake was like an orgasm in your mouth.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5224c1da11d2bcafc67dfb44', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Leo', 'lastName': 'M', 'countryCode': 'US'}, {'firstName': 'Catherine', 'lastName': 'T', 'countryCode': 'US'}, {'firstName': 'Letizia Maria', 'lastName': 'S', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Juan', 'lastName': 'M', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/YwG581', 'timeZone': 'America/New_York', 'listed': {'count': 7, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 7, 'items': [{'id': '563d3b64cd10a83b1cc15cd4', 'name': 'Restaurants to Try - NYC', 'description': '', 'type': 'others', 'user': {'firstName': 'Emily', 'las ...
#                          ID                    Name  Likes  Rating  Tips
# 0  511edb6de4b0d58346fd272d  Patrizia's Of Woodlawn     18     8.6    14
# ( 1 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd30462594c16c8d13f'}, 'response': {'venue': {'id': '4bf96ae65317a593d837017f', 'name': "Enzo's", 'contact': {'phone': '7184093828', 'formattedPhone': '(718) 409-3828'}, 'location': {'address': '1998 Williamsbridge Rd', 'lat': 40.854232311821725, 'lng': -73.85436243306151, 'labeledLatLngs': [{'label': 'display', 'lat': 40.854232311821725, 'lng': -73.85436243306151}, {'label': 'entrance', 'lat': 40.854116, 'lng': -73.854132}], 'postalCode': '10461', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1998 Williamsbridge Rd', 'Bronx, NY 10461', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/enzos/4bf96ae65317a593d837017f', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 12}, 'url': 'http://www.enzosofthebronx.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 29, 'groups': [{'type': 'others', 'count': 29, 'items': []}], 'summary': '29 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.7, 'ratingColor': '73CF42', 'ratingSignals': 30, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/enzos/4bf96ae65317a593d837017f/menu', 'mobileUrl': 'https://foursquare.com/v/4bf96ae65317a593d837017f/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 31, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 31, 'items': [{'id': '4ef923530e61a0846ef01016', 'createdAt': 1324950355, 'source': {'name': 'Hipster', 'url': 'http://www.hipster.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/PMDKJWEHUBIVYWO3WW3AU0BHY5LCV3C53AAN2OA5IUKI441Y.jpg', 'width': 720, 'height': 480, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1274637030, 'tips': {'count': 12, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 12, 'items': [{'id': '5444272e498ecb4a7f552c95', 'createdAt': 1413752622, 'text': "Everything here is absolutely delicious, and incredibly authentic. The chicken parm was the best I've ever had and the wait staff was extremely nice and attentive too!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5444272e498ecb4a7f552c95', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'firstName': 'Dani', 'lastName': 'O', 'countryCode': 'US'}, {'firstName': 'Whitney', 'lastName': 'S', 'countryCode': 'US'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Corley', 'lastName': 'S', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/cr64JF', 'timeZone': 'America/New_York', 'listed': {'count': 17, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 17, 'items': [{'id': '558b075d498e58a049f20e97', 'name': 'Best Places to Eat', 'description': 'These are my favorite places to eat.', 'type': 'others', 'user': {'firstName': 'Avery', 'lastName': 'P', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/averyputter/list/best-places-to-eat', 'canonicalUrl': 'https://foursquare.com/averyputter/list/best-places-to-eat', 'createdAt': 1435174749, 'updatedAt': 1499225732, 'followers': {'count': 0}, 'listItems': {'count': 6, 'items': [{'id': 'v4bf96ae65317a593d837017f', 'createdAt': 1499225732}]}}, {'id': '5a7722e2d41bb734058bbea0', 'name': 'Nyc try', 'description': '', 'type': 'others', 'user': {'firstName': 'Brian', 'countryCode': 'US'}, 'editable': F ...
#                          ID    Name  Likes  Rating  Tips
# 0  4bf96ae65317a593d837017f  Enzo's     29     8.7    12
# ( 2 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd31c315e2680f0c599'}, 'response': {'venue': {'id': '4b47f069f964a5208c4426e3', 'name': 'Pasta Pasta', 'contact': {'phone': '7188929634', 'formattedPhone': '(718) 892-9634'}, 'location': {'address': '2023 Williamsbridge Rd', 'lat': 40.85478806485715, 'lng': -73.85492881053774, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85478806485715, 'lng': -73.85492881053774}, {'label': 'entrance', 'lat': 40.854792, 'lng': -73.855184}], 'postalCode': '10461', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2023 Williamsbridge Rd', 'Bronx, NY 10461', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/pasta-pasta/4b47f069f964a5208c4426e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 8}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 9, 'groups': [{'type': 'others', 'count': 9, 'items': [{'firstName': 'Michael', 'lastName': 'R', 'countryCode': 'US'}, {'firstName': 'Sue', 'lastName': 'E', 'countryCode': 'US'}, {'firstName': 'Alex', 'lastName': 'P', 'countryCode': 'US'}, {'firstName': 'Myriam', 'lastName': 'C', 'countryCode': 'US'}]}], 'summary': '9 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.5, 'ratingColor': 'FFC800', 'ratingSignals': 14, 'delivery': {'id': '2078644', 'url': 'https://www.seamless.com/menu/pasta-pasta-inc-2023-williamsbridge-road-bronx/2078644?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2078644', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '5d8681ae6d0390000829909a', 'createdAt': 1569096110, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/42085913_1WAYLfAPfivinkThkpeZaqPUF46-YTi6yWfCjNP4b3c.jpg', 'width': 1346, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1263005801, 'tips': {'count': 8, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 8, 'items': [{'id': '5312697111d292c46531f55e', 'createdAt': 1393715569, 'text': "Someone just keeled over right next to me! It's like the nursing home of Italian food....no pun intended!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5312697111d292c46531f55e', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': []}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Daniel', 'lastName': 'F', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/8eIstm', 'timeZone': 'America/New_York', 'listed': {'count': 4, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 4, 'items': [{'id': '4e6109deb3ad629a3a4ac4cb', 'name': '20 Favorite Restaurants', 'description': '', 'type': 'others', 'user': {'firstName': 'Dane', 'lastName': 'C', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/13219682/list/20-favorite-restaurants', 'canonicalUrl': 'https://foursquare.com/user/13219682/list/20-favorite-restaurants', 'createdAt': 1314982366, 'updatedAt': 1365337523, 'followers': {'count': 1}, 'listItems': {'count': 4, 'items': [{'id': 'v4b47f069f964a5208c4426e3', 'createdAt': 1314982366}]}}, ...
#                          ID         Name  Likes  Rating  Tips
# 0  4b47f069f964a5208c4426e3  Pasta Pasta      9     6.5     8
# ( 3 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd34c12e0466f518fb3'}, 'response': {'venue': {'id': '4514ed4df964a520e5391fe3', 'name': "Artie's Steak and Seafood", 'contact': {'phone': '7188859885', 'formattedPhone': '(718) 885-9885', 'twitter': 'artiescrazy'}, 'location': {'address': '394 City Island Ave', 'lat': 40.849542144998146, 'lng': -73.78731730033616, 'labeledLatLngs': [{'label': 'display', 'lat': 40.849542144998146, 'lng': -73.78731730033616}, {'label': 'entrance', 'lat': 40.849596, 'lng': -73.787218}], 'postalCode': '10464', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['394 City Island Ave', 'Bronx, NY 10464', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/arties-steak-and-seafood/4514ed4df964a520e5391fe3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 28}, 'url': 'http://www.artiescityisland.com', 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 46, 'groups': [{'type': 'others', 'count': 46, 'items': []}], 'summary': '46 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 52, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/arties-steak-and-seafood/4514ed4df964a520e5391fe3/menu', 'mobileUrl': 'https://foursquare.com/v/4514ed4df964a520e5391fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 47, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 47, 'items': [{'id': '512031f8e4b00ebaf9f770b8', 'createdAt': 1361064440, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/38056345_YxrGWXl-qI1x3rbV3Uu_v2XJwDacrRYzFlEWyQ_28mY.jpg', 'width': 717, 'height': 959, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1158999373, 'tips': {'count': 28, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 28, 'items': [{'id': '534eeafa498e3b48057eebd7', 'createdAt': 1397680890, 'text': "If you're a fan of seafood, make sure to travel to City Island and enjoy the delicious dishes of Arties, particularly the captains platter & the Broiled Fisherman Platters!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/534eeafa498e3b48057eebd7', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': []}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'New York Habitat', 'countryCode': 'US', 'type': 'chain'}}]}]}, 'shortUrl': 'http://4sq.com/aMr4jJ', 'timeZone': 'America/New_York', 'listed': {'count': 25, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 25, 'items': [{'id': '519af3b0498e6e1b3705d215', 'name': 'wc/hv to try', 'description': '', 'type': 'others', 'user': {'firstName': 'Kobie', 'lastName': 'W', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/56807089/list/wchv-to-try', 'canonicalUrl': 'https://foursquare.com/user/56807089/list/wchv-to-try', 'createdAt': 1369109424, 'updatedAt': 1623503507, 'followers': {'count': 2}, 'listItems': {'count': 295, 'items': [{'id': 'v4514ed4df964a520e5391fe3', 'createdAt': 1402232697}]}}, {'id': '51ade096498e47fa587bb37a', 'name': 'The List', 'description': '', 'type': 'others', 'user': {'firstName': 'Paul', 'lastName': 'K', ...
#                          ID                       Name  Likes  Rating  Tips
# 0  4514ed4df964a520e5391fe3  Artie's Steak and Seafood     46     8.3    28
# ( 4 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd4bd0a7d1e4c8bafd1'}, 'response': {'venue': {'id': '4b1712a8f964a520dbc123e3', 'name': 'Jolly Tinker', 'contact': {'phone': '3477265644', 'formattedPhone': '(347) 726-5644'}, 'location': {'address': '2875 Webster Ave', 'lat': 40.86745127461597, 'lng': -73.88353583600046, 'labeledLatLngs': [{'label': 'display', 'lat': 40.86745127461597, 'lng': -73.88353583600046}, {'label': 'entrance', 'lat': 40.867508, 'lng': -73.883501}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2875 Webster Ave', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/jolly-tinker/4b1712a8f964a520dbc123e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 4}, 'url': 'https://www.jollytinkers.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 19, 'groups': [{'type': 'others', 'count': 19, 'items': []}], 'summary': '19 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 20, 'delivery': {'id': '1119310', 'url': 'https://www.seamless.com/menu/jolly-tinker-2875-webster-ave-bronx/1119310?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1119310', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 33, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 33, 'items': [{'id': '51b7aaad498e3a4a36209486', 'createdAt': 1370991277, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/7379245_oOFsFBgxqJttOWqgLsAKYRkK4ZMMMVJ-h0zbhEe3z_A.jpg', 'width': 612, 'height': 612, 'visibility': 'public'}]}]}, 'venuePage': {'id': '553087284'}, 'reasons': {'count': 0, 'items': []}, 'description': 'Are you looking for a fusion restaurant in Bronxville, New York? Jolly Tinker is a bar and grill with something on the menu for everyone. The menu includes chicken wings, pastas, burgers, steak, seafood, and more. Jolly Tinker also offers taco Tuesday specials, wing Wednesday specials, Jolly Mond...', 'page': {'user': {'firstName': 'Jolly Tinker', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4b1712a8f964a520dbc123e3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1259803304, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5a4853d56fa81f38bdd55f45', 'createdAt': 1514689493, 'text': 'Jolly Tinker is OPEN! Nicely renovated..... 30Dec2017', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5a4853d56fa81f38bdd55f45', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Jolly', 'lastName': 't', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/8HeAas', 'timeZone': 'America/New_York', 'listed': {'count': 13, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 13, 'items': [{'id': '4e71778ecc3fbc6bca78f82b', 'name': 'Top picks for Bars', 'description': '', 'type': 'others', 'user': {'firstName':  ...
#                          ID          Name  Likes  Rating  Tips
# 0  4b1712a8f964a520dbc123e3  Jolly Tinker     19     7.6     4
# ( 5 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd44cb9c1507b1fa2f6'}, 'response': {'venue': {'id': '4b10591af964a5205f6e23e3', 'name': "Patricia's", 'contact': {'phone': '7184099069', 'formattedPhone': '(718) 409-9069', 'twitter': 'patriciasnyc'}, 'location': {'address': '1082 Morris Park Ave', 'lat': 40.84931298339339, 'lng': -73.85353576737785, 'labeledLatLngs': [{'label': 'display', 'lat': 40.84931298339339, 'lng': -73.85353576737785}, {'label': 'entrance', 'lat': 40.849229, 'lng': -73.853395}], 'postalCode': '10461', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1082 Morris Park Ave', 'Bronx, NY 10461', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/patricias/4b10591af964a5205f6e23e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 39}, 'url': 'http://www.patriciasnyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 84, 'groups': [{'type': 'others', 'count': 84, 'items': []}], 'summary': '84 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 82, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/patricias/4b10591af964a5205f6e23e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b10591af964a5205f6e23e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 86, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 86, 'items': [{'id': '58ffca495c1ba27da144f19e', 'createdAt': 1493158473, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/410402136_hSIRilYgmzCTOPJ8kV9Y-6vH1Kel7RsEZpOOlSNA0SI.jpg', 'width': 1500, 'height': 1000, 'visibility': 'public'}]}]}, 'venuePage': {'id': '410402136'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Our passion for the cuisine, wine, and regions of Italy are reflected throughout our restaurant.', 'page': {'user': {'firstName': "Patricia's", 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4b10591af964a5205f6e23e3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1259362586, 'tips': {'count': 39, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 39, 'items': [{'id': '51956d40498e3a08742c24f6', 'createdAt': 1368747328, 'text': 'This is the best Patricias by far, Yeah its a whole in the Wall but the food is amazing', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51956d40498e3a08742c24f6', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Märlënë', 'lastName': 'B', 'countryCode': 'US'}, {'firstName': 'Jon-Erik', 'lastName': 'A', 'countryCode': 'US'}, {'firstName': 'Rachel', 'lastName': 'B', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'El', 'lastName': 'B', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/9hOC8J', 'timeZone': 'America/New_York', 'listed': {'count': 74, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 74, 'items': [{'id': '4efdc70bbe7bbcd4f192a53b', 'name': 'Bronx Mu ...
#                          ID        Name  Likes  Rating  Tips
# 0  4b10591af964a5205f6e23e3  Patricia's     84     8.5    39
# ( 6 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd4b948963e37a8aa70'}, 'response': {'venue': {'id': '4acf80aef964a52025d420e3', 'name': "Tino's Delicatessen", 'contact': {'phone': '7187339879', 'formattedPhone': '(718) 733-9879'}, 'location': {'address': '2410 Arthur Ave', 'crossStreet': 'E. 187 St.', 'lat': 40.85588217093613, 'lng': -73.88716612015719, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85588217093613, 'lng': -73.88716612015719}, {'label': 'entrance', 'lat': 40.855816, 'lng': -73.887189}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2410 Arthur Ave (E. 187 St.)', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/tinos-delicatessen/4acf80aef964a52025d420e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d146941735', 'name': 'Deli / Bodega', 'pluralName': 'Delis / Bodegas', 'shortName': 'Deli / Bodega', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1f9941735', 'name': 'Food & Drink Shop', 'pluralName': 'Food & Drink Shops', 'shortName': 'Food & Drink', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 48}, 'url': 'http://www.tinosdeli.com', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 147, 'groups': [{'type': 'others', 'count': 147, 'items': []}], 'summary': '147 Likes'}, 'dislike': False, 'ok': False, 'rating': 9.1, 'ratingColor': '00B551', 'ratingSignals': 99, 'delivery': {'id': '2443956', 'url': 'https://www.seamless.com/menu/tinos-delicatessen-2410-arthur-ave-ny/2443956?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2443956', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/tinos-delicatessen/4acf80aef964a52025d420e3/menu', 'mobileUrl': 'https://foursquare.com/v/4acf80aef964a52025d420e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 78, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 78, 'items': [{'id': '544818c4498e6354368255e9', 'createdAt': 1414011076, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/89498162_C7BaEoWW6XTbj6MZ_6LI3lBXR6i4EVgpSihEGZk9RO4.jpg', 'width': 640, 'height': 640, 'visibility': 'public'}]}]}, 'venuePage': {'id': '65699297'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'page': {'user': {'firstName': "Tino's Delicatessen", 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4acf80aef964a52025d420e3'}, 'tips': {'count': 2}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1255112878, 'tips': {'count': 48, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 48, 'items': [{'id': '54b00871498e43e9430459ef', 'createdAt': 1420822641, 'text': "Tino's Deli knows classic heroes, and the $7.95 chicken parm sandwich is the best of the best. Thick Italian bread envelops plump pieces of breaded chicken, all smothered in delectable mozzarella.", 'type': 'user', 'url': 'http://gothamist.com/2014/12/04/best_sandwiches_nyc.php', 'canonicalUrl': 'https://fours ...
#                          ID                 Name  Likes  Rating  Tips
# 0  4acf80aef964a52025d420e3  Tino's Delicatessen    147     9.1    48
# ( 7 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd570876e2559a010bc'}, 'response': {'venue': {'id': '59050f51b23dfa5f6649e678', 'name': 'Arthur Avenue Fiasco', 'contact': {'phone': '7186180806', 'formattedPhone': '(718) 618-0806'}, 'location': {'address': '2376 Arthur Ave', 'crossStreet': '187th street', 'lat': 40.854844, 'lng': -73.887908, 'labeledLatLngs': [{'label': 'display', 'lat': 40.854844, 'lng': -73.887908}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2376 Arthur Ave (187th street)', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/arthur-avenue-fiasco/59050f51b23dfa5f6649e678', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 4}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 10, 'groups': [{'type': 'others', 'count': 10, 'items': []}], 'summary': '10 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.7, 'ratingColor': '73CF42', 'ratingSignals': 10, 'delivery': {'id': '935894', 'url': 'https://www.seamless.com/menu/arthur-ave-fiasco-2376-arthur-ave-bronx/935894?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=935894', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 10, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 10, 'items': [{'id': '5e25fa1d48a5ed000816c0c7', 'createdAt': 1579547165, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/338226916_SQD4bqr83MqBsXrxc8Gn1KPqrcB4ErJOw8MIei3Jk-0.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1493503825, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5c97ea2379f6c7002ccc2e46', 'createdAt': 1553459747, 'text': 'Everything is good here!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c97ea2379f6c7002ccc2e46', 'photo': {'id': '5c991e01a8eb60002c0368af', 'createdAt': 1553538561, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/77062845_nm2nnAhhANHai6FP7edZKsGkxyA9bWIkOGMwOzjEdr8.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/77062845_nm2nnAhhANHai6FP7edZKsGkxyA9bWIkOGMwOzjEdr8.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Mike', 'lastName': 'H', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2pJzCjk', 'timeZone': 'America/New_York', 'listed': {'count': 12, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 12, 'items': [{'id': '5f28b1b1c79cdb0a8eb7694b', 'name': 'ARTHUR Ave', 'description': '', 'type': 'others', 'user': {'firstName': 'Jamie', 'lastName': 'J', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/143935834/list/arthur-ave', 'canonicalUrl': 'https://foursquare.com/user/143935834/list/arthur-ave', 'createdAt': 1596502449, 'updatedAt': 1596821403, 'photo': {'id': '544818c4498e6354368255e9', 'createdAt': 1414011076, 'prefix': 'https://fastly.4sqi.net/img/gen ...
#                          ID                  Name  Likes  Rating  Tips
# 0  59050f51b23dfa5f6649e678  Arthur Avenue Fiasco     10     8.7     4
# ( 8 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd528572c5d6c468cd6'}, 'response': {'venue': {'id': '4af71916f964a520cf0522e3', 'name': "Michaelangelo's Coal Fired Brick Oven Pizza Restaurant", 'contact': {'phone': '3475907650', 'formattedPhone': '(347) 590-7650'}, 'location': {'address': '2477 Arthur Ave', 'lat': 40.85741189614754, 'lng': -73.88646821282298, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85741189614754, 'lng': -73.88646821282298}, {'label': 'entrance', 'lat': 40.857301, 'lng': -73.886231}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2477 Arthur Ave', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/michaelangelos-coal-fired-brick-oven-pizza-restaurant/4af71916f964a520cf0522e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 25}, 'url': 'http://michaelangelosbrickoven.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 39, 'groups': [{'type': 'others', 'count': 39, 'items': []}], 'summary': '39 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.9, 'ratingColor': 'C5DE35', 'ratingSignals': 37, 'delivery': {'id': '421532', 'url': 'https://www.seamless.com/menu/michaelangelos-2477-arthur-ave-bronx/421532?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=421532', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/michaelangelos-coal-fired-brick-oven-pizza-restaurant/4af71916f964a520cf0522e3/menu', 'mobileUrl': 'https://foursquare.com/v/4af71916f964a520cf0522e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 50, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 50, 'items': [{'id': '504ff085e4b032bac6b4af9c', 'createdAt': 1347416197, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/6AA2UkeJOIewk3WbcdE2VXJ846RTtkEUUFSpm83S4zc.jpg', 'width': 432, 'height': 720, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1257707798, 'tips': {'count': 25, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 25, 'items': [{'id': '4f2ae186e4b09f4f37d31bf0', 'createdAt': 1328210310, 'text': 'Their calzones are amazing!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4f2ae186e4b09f4f37d31bf0', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Diana', 'lastName': 'R', 'countryCode': 'US'}, {'firstName': 'Pascual', 'countryCode': 'US'}, {'firstName': 'Gabriel', 'lastName': 'J', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'firstName': 'Stephanie', 'lastName': 'S', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/9oZ9aA', 'timeZone': 'America/New_York', 'listed': {'count': 25, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 25, 'items': [{'id': ' ...
#                          ID  \
# 0  4af71916f964a520cf0522e3
#
#                                                 Name  Likes  Rating  Tips
# 0  Michaelangelo's Coal Fired Brick Oven Pizza Re...     39     7.9    25
# ( 9 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd5b948963e37a8ad19'}, 'response': {'venue': {'id': '4bb6470cef159c7465b275f7', 'name': 'Calabria Pork Store', 'contact': {'phone': '7183675145', 'formattedPhone': '(718) 367-5145'}, 'location': {'address': '2338 Arthur Ave', 'lat': 40.85414529023418, 'lng': -73.88877606219484, 'labeledLatLngs': [{'label': 'display', 'lat': 40.85414529023418, 'lng': -73.88877606219484}, {'label': 'entrance', 'lat': 40.854096, 'lng': -73.888659}], 'postalCode': '10458', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2338 Arthur Ave', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/calabria-pork-store/4bb6470cef159c7465b275f7', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1f5941735', 'name': 'Gourmet Shop', 'pluralName': 'Gourmet Shops', 'shortName': 'Gourmet', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 13}, 'url': 'https://calabriapork.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 31, 'groups': [{'type': 'others', 'count': 31, 'items': []}], 'summary': '31 Likes'}, 'dislike': False, 'ok': False, 'rating': 9.0, 'ratingColor': '00B551', 'ratingSignals': 19, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 58, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 58, 'items': [{'id': '531b71e0498e719fe11e113d', 'createdAt': 1394307552, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/37560_XRuPonXLzVbZloFuVHo1VWpBR__ESiI_BhDY2Ip1_Vo.jpg', 'width': 640, 'height': 640, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1270236940, 'tips': {'count': 13, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 13, 'items': [{'id': '5192efca498e0bb7e8b1488f', 'createdAt': 1368584138, 'text': "Iconic source for Italian cured meats on the Bronx's Arthur Avenue. Try the wickedly hot soppresata or the spreadable n'duja.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5192efca498e0bb7e8b1488f', 'lang': 'en', 'likes': {'count': 10, 'groups': [{'type': 'others', 'count': 10, 'items': []}], 'summary': '10 likes'}, 'logView': True, 'agreeCount': 10, 'disagreeCount': 0, 'todo': {'count': 8}, 'user': {'firstName': 'Serious Eats', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/bADF6Y', 'timeZone': 'America/New_York', 'listed': {'count': 73, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 73, 'items': [{'id': '50379b8de4b0b4924bccca94', 'name': 'Bronx-To-Do List', 'description': '', 'type': 'others', 'user': {'firstName': 'D', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/4174003/list/bronxtodo-list', 'canonicalUrl': 'https://foursquare.com/user/4174003/list/bronxtodo-list', 'createdAt': 1345821581, 'updatedAt': 1406668591, 'photo': {'id': '4e7bb0fc45dd3b0e49bb387b', 'createdAt': 1316729084, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/05YJ2ENHLKZ4AEBQB5P4V44WK2ZEOHJ4SPJ3URJBU1GIWFJS.jpg', 'width': 720, 'height': 540, 'visibility': 'public'}, 'followers': {'count': 25}, 'listItems': {'count': 149, 'items': [{'id': 'v4bb6470cef159c7465b275f7', 'createdAt': 1348842841, 'photo': {'id': '4f5bbde1e4b07bddee902d96', 'createdAt': 1331412449, 'prefix': 'https://f ...
#                          ID                 Name  Likes  Rating  Tips
# 0  4bb6470cef159c7465b275f7  Calabria Pork Store     31     9.0    13
# ( 10 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0dd52f2b726e6ee21ac2'}, 'response': {'venue': {'id': '4b5514c4f964a5207cda27e3', 'name': "Enzo's", 'contact': {'phone': '7187334455', 'formattedPhone': '(718) 733-4455'}, 'location': {'address': '2339 Arthur Ave', 'lat': 40.854354554251444, 'lng': -73.88864359312625, 'labeledLatLngs': [{'label': 'display', 'lat': 40.854354554251444, 'lng': -73.88864359312625}, {'label': 'entrance', 'lat': 40.854339, 'lng': -73.888759}], 'postalCode': '10458', 'cc': 'US', 'neighborhood': 'Belmont', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2339 Arthur Ave', 'Bronx, NY 10458', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/enzos/4b5514c4f964a5207cda27e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 19}, 'url': 'http://enzosbronxrestaurant.com', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 44, 'groups': [{'type': 'others', 'count': 44, 'items': []}], 'summary': '44 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.4, 'ratingColor': '73CF42', 'ratingSignals': 42, 'delivery': {'id': '2080498', 'url': 'https://www.seamless.com/menu/enzos-of-arthur-avenue-2339-arthur-avenue-bronx/2080498?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2080498', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/enzos/4b5514c4f964a5207cda27e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b5514c4f964a5207cda27e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 41, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 41, 'items': [{'id': '4ff25033e4b0a2a642e90931', 'createdAt': 1341280307, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/7uPgd-WTyhOcvcsVLbrQmN7S_aiFv33Qsd_C7M0q56w.jpg', 'width': 720, 'height': 540, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1263867076, 'tips': {'count': 19, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 19, 'items': [{'id': '51e9bc2c498e66e8bac8e3c1', 'createdAt': 1374272556, 'text': 'The veal Enzo is amazing. Wow. #food', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51e9bc2c498e66e8bac8e3c1', 'photo': {'id': '51e9bc3d498ea4215aacf59f', 'createdAt': 1374272573, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/47952_dmDp1-dWorUwHiWJk4fZkAdTovgOuEpT2rMUQ_CU3Tc.jpg', 'width': 960, 'height': 720, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/47952_dmDp1-dWorUwHiWJk4fZkAdTovgOuEpT2rMUQ_CU3Tc.jpg', 'lang': 'en', 'likes': {'count': 6, 'groups': [{'type': 'others', 'count': 6, 'items': [{'firstName': "Meşe's İşkembe", 'lastName': 'M', 'countryCode': 'TR'}, {'firstName': 'Murat', 'countryCode': 'TR'}, {'firstName': 'Göksu İç Mimarlık', 'address': '', 'city': '', 'state': '', 'countryCode': 'TR'}]}], 'summary': '6 likes'}, 'logView': True, 'agreeCount': 6, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Brian', 'lastName': 'P', 'countryCode': 'US'}}]}]} ...
#                          ID    Name  Likes  Rating  Tips
# 0  4b5514c4f964a5207cda27e3  Enzo's     44     8.4    19
# ( 11 / 236 ) processed
# ...
#                          ID     Name  Likes  Rating  Tips
# 0  49c4ff90f964a520da561fe3  Fragole    108     7.4    46
# ( 47 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0ddf28ef2f25c4ca8aa7'}, 'response': {'venue': {'id': '5766ad56498ebf269c3737d2', 'name': 'Gersi', 'contact': {'phone': '3478895077', 'formattedPhone': '(347) 889-5077', 'twitter': 'gersirestaurant'}, 'location': {'address': '316 Court St', 'crossStreet': 'Sackett Street', 'lat': 40.68337949868895, 'lng': -73.99549228030504, 'labeledLatLngs': [{'label': 'display', 'lat': 40.68337949868895, 'lng': -73.99549228030504}], 'postalCode': '11231', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['316 Court St (Sackett Street)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/gersi/5766ad56498ebf269c3737d2', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 17}, 'url': 'http://www.gersirestaurant.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 29, 'groups': [{'type': 'others', 'count': 29, 'items': []}], 'summary': '29 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.2, 'ratingColor': 'C5DE35', 'ratingSignals': 66, 'delivery': {'id': '344242', 'url': 'https://www.seamless.com/menu/gersi-316-court-st-brooklyn/344242?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=344242', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.gersirestaurant.com/menu/', 'mobileUrl': 'http://www.gersirestaurant.com/menu/', 'externalUrl': 'http://www.gersirestaurant.com/menu/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 39, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 39, 'items': [{'id': '604eadeefd8ad76e8a3e9964', 'createdAt': 1615769070, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/12795256_02yICn89loyTWYyPbb9DaEhOcz-mRiPMIHJCUYIyaUs.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1466346838, 'tips': {'count': 17, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 17, 'items': [{'id': '5d6bd3e8d5696200065e8bfc', 'createdAt': 1567347688, 'text': 'This restaurant itself is so cute - great backdoor area. Burrata was good. Mains were OK', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d6bd3e8d5696200065e8bfc', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'J', 'lastName': 'B', 'countryCode': 'US'}, 'authorInteractionType': 'meh'}]}]}, 'shortUrl': 'http://4sq.com/1Yz9cKr', 'timeZone': 'America/New_York', 'listed': {'count': 60, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 60, 'items': [{'id': '57c34d0a498e67759ae58d6c', 'name': 'Park Slope, and around', 'description': 'My favorite places in my neighborhood', 'type': 'others', 'user': {'firstName': 'Valentin', 'lastName': 'G', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/valentinguerin/list/park-slope-and-around', 'canonicalUrl': 'https://foursquare.com/valentinguerin/list/park-slope-and-around', 'createdAt': 1472417034, 'updatedAt': 1623590066, 'photo': {'id': '516b1d24e4b0ab970085bfcb', 'createdAt': 1365974308, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/18054_KaDEDHzd3 ...
#                          ID   Name  Likes  Rating  Tips
# 0  5766ad56498ebf269c3737d2  Gersi     29     7.2    17
# ( 48 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0ddfb5ab84411e6d79b8'}, 'response': {'venue': {'id': '4a32d7ebf964a520a29a1fe3', 'name': 'Enoteca on Court', 'contact': {'phone': '7182431000', 'formattedPhone': '(718) 243-1000', 'twitter': 'enotecaoncourt1', 'facebook': '100640606612', 'facebookName': 'ENOTECA ON COURT STREET'}, 'location': {'address': '347 Court St', 'crossStreet': 'at Union St.', 'lat': 40.6822145298343, 'lng': -73.99594672669618, 'labeledLatLngs': [{'label': 'display', 'lat': 40.6822145298343, 'lng': -73.99594672669618}], 'postalCode': '11231', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['347 Court St (at Union St.)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/enoteca-on-court/4a32d7ebf964a520a29a1fe3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d123941735', 'name': 'Wine Bar', 'pluralName': 'Wine Bars', 'shortName': 'Wine Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 27}, 'url': 'http://marcopoloristorante.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 60, 'groups': [{'type': 'others', 'count': 60, 'items': []}], 'summary': '60 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.5, 'ratingColor': 'FFC800', 'ratingSignals': 59, 'delivery': {'id': '297606', 'url': 'https://www.seamless.com/menu/enoteca-on-court-347-court-st-brooklyn/297606?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=297606', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/enoteca-on-court/4a32d7ebf964a520a29a1fe3/menu', 'mobileUrl': 'https://foursquare.com/v/4a32d7ebf964a520a29a1fe3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 73, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 73, 'items': [{'id': '5a8aefec4816f04619985146', 'createdAt': 1519054828, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/472929014_IsHot8jiSY6ua-pUdAL0UAjD4P90Ir2O2YVNT73PynQ.jpg', 'width': 1500, 'height': 1000, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': "Italian comforts, meet innovative tastes. At our shared plate restaurant and wine bar, we're serving chef-driven dishes in a cozy space.", 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://marcopoloristorante.com'}]}}, 'user': {'firstName': 'Marco Polo Corp', 'countryCode': 'US', 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1244846059, 'tips': {'count': 27, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 27, 'items': [{'id': '53363185498e68b93063510c', 'createdAt': 1396060549, 'text': 'Stick to the pizzas here. Artichoke or mushroom w/ truffle oil are A+ Avoid the pastas. The pesto is bland. The gnocchi gorgonzola gets old real quick. Want pasta? Go to Fragole one block south.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/53363185498e68b93063510c', 'photo': {'id': '533c6ae5498e18e8d6f0f598', 'createdAt': 139 ...
#                          ID              Name  Likes  Rating  Tips
# 0  4a32d7ebf964a520a29a1fe3  Enoteca on Court     60     6.5    27
# ( 49 / 236 ) processed
# {'meta': {'code': 200, 'requestId': '60df0ddf950a526801223bb2'}, 'response': {'venue': {'id': '4ab98ab8f964a520cf7f20e3', 'name': 'Marco Polo Ristorante', 'contact': {'phone': '7188525015', 'formattedPhone': '(718) 852-5015', 'twitter': 'marcopolorist'}, 'location': {'address': '345 Court St', 'crossStreet': 'at Union St', 'lat': 40.68231096732147, 'lng': -73.99591141723491, 'labeledLatLngs': [{'label': 'display', 'lat': 40.68231096732147, 'lng': -73.99591141723491}, {'label': 'entrance', 'lat': 40.682241, 'lng': -73.995809}], 'postalCode': '11231', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['345 Court St (at Union St)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/marco-polo-ristorante/4ab98ab8f964a520cf7f20e3', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 14}, 'url': 'http://marcopoloristorante.com', 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 33, 'groups': [{'type': 'others', 'count': 33, 'items': []}], 'summary': '33 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.0, 'ratingColor': 'FFC800', 'ratingSignals': 32, 'delivery': {'id': '556391', 'url': 'https://www.seamless.com/menu/marco-polo-ristorante-345-court-st-brooklyn/556391?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=556391', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/marco-polo-ristorante/4ab98ab8f964a520cf7f20e3/menu', 'mobileUrl': 'https://foursquare.com/v/4ab98ab8f964a520cf7f20e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 59, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 59, 'items': [{'id': '51bcf77d498e8e4e6918fd4c', 'createdAt': 1371338621, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/18735538_7S92Y8RL2lFgvDkC4HrgFMkSmzKnJJiZ7sZmKlejuLQ.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Bringing together good taste, good times, and good people since 1983. Join us for authentic Italian eats and an impeccable happy hour.', 'page': {'pageInfo': {'links': {'count': 1, 'items': [{'url': 'http://marcopoloristorante.com'}]}}, 'user': {'firstName': 'Marco Polo Corp', 'countryCode': 'US', 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1253673656, 'tips': {'count': 14, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 14, 'items': [{'id': '4ff8d3eee4b083d14ceb2f33', 'createdAt': 1341707246, 'text': 'Start with 48 oysters & a bottle of champagne and end with the chocolate cake. Ask the live pianist to sing your fave Sinatra song. This spot, my friends, is Old School Brooklyn Italian.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4ff8d3eee4b083d14ceb2f33', 'photo': {'id': '4ff8d3f3e4b0903668f82eb3', 'createdAt': 1341707251, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/Iz9Z_Y1La4SJ6 ...
#                          ID                   Name  Likes  Rating  Tips
# 0  4ab98ab8f964a520cf7f20e3  Marco Polo Ristorante     33     6.0    14
# ( 50 / 236 ) processed
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '60df0de0bd0a7d1e4c8bcfc6'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c5e93b13706a> in <module>
#       5     Borough,Neighborhood,ID,Name=row
#       6     try:
# ----> 7         venue_details=get_venue_details(ID)
#       8         print(venue_details)
#       9         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-3-84733b02a2aa> in get_venue_details(venue_id)
#      48     results = requests.get(url).json()
#      49     print(results)
# ---> 50     venue_data=results['response']['venue']
#      51     venue_details=[]
#      52     try:
#
# KeyError: 'venue'

# %%
italian_rest_stats_ny.to_csv('italian_rest_stats_ny_csv.csv') # As I move through this project I continue to save data to a .csv file

# %%
italian_rest_stats_ny.shape
# Out:
# (50, 7)

# %%
italian_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       50 non-null     object
#  1   Neighborhood  50 non-null     object
#  2   ID            50 non-null     object
#  3   Name          50 non-null     object
#  4   Likes         50 non-null     object
#  5   Rating        50 non-null     float64
#  6   Tips          50 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.9+ KB

# %%
italian_rest_stats_ny['Likes'] = italian_rest_stats_ny['Likes'].astype('float64')
italian_rest_stats_ny['Tips'] = italian_rest_stats_ny['Tips'].astype('float64')
italian_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       50 non-null     object
#  1   Neighborhood  50 non-null     object
#  2   ID            50 non-null     object
#  3   Name          50 non-null     object
#  4   Likes         50 non-null     float64
#  5   Rating        50 non-null     float64
#  6   Tips          50 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 2.9+ KB

# %%
italian_rest_stats_ny.describe()
# Out:
#             Likes     Rating       Tips
# count   50.000000  50.000000  50.000000
# mean    32.600000   6.944000  16.820000
# std     31.961073   2.497604  13.755429
# min      0.000000   0.000000   0.000000
# 25%     11.000000   6.725000   6.000000
# 50%     22.000000   7.650000  13.500000
# 75%     45.500000   8.375000  26.500000
# max    147.000000   9.200000  48.000000

# %%
# Resturant with maximum Likes
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                            Bronx
# Neighborhood                     Belmont
# ID              4acf80aef964a52025d420e3
# Name                 Tino's Delicatessen
# Likes                              147.0
# Rating                               9.1
# Tips                                48.0
# Name: 6, dtype: object

# %%
# Resturant with maximum Ratings
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                         Brooklyn
# Neighborhood                    Bushwick
# ID              5a98aed16a59506d7a60d67c
# Name                          Carmenta’s
# Likes                               62.0
# Rating                               9.2
# Tips                                22.0
# Name: 38, dtype: object

# %%
# Resturant with maximum Tips
italian_rest_stats_ny.iloc[italian_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                            Bronx
# Neighborhood                     Belmont
# ID              4acf80aef964a52025d420e3
# Name                 Tino's Delicatessen
# Likes                              147.0
# Rating                               9.1
# Tips                                48.0
# Name: 6, dtype: object

# %%
ny_neighborhood_stats=italian_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#           Neighborhood  Average Rating
# 2   Bedford Stuyvesant        9.200000
# 6             Bushwick        9.200000
# 19            Woodlawn        8.600000
# 13         Morris Park        8.500000
# 16      Pelham Gardens        8.400000
# 8          City Island        8.300000
# 9          Cobble Hill        8.066667
# 18         Sunset Park        7.700000
# 12           Gravesend        7.700000
# 1         Bedford Park        7.600000

# %%
ny_borough_stats=italian_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#     Borough  Average Rating
# 0     Bronx        7.062069
# 1  Brooklyn        6.780952

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Average rating of Italian Restaurants for each Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('Average Rating', fontsize=15)
italian_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar', color=clr)
plt.legend()
plt.show()

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=8.0]
ny_neighborhood_stats
# Out:
#           Neighborhood  Average Rating
# 2   Bedford Stuyvesant        9.200000
# 6             Bushwick        9.200000
# 8          City Island        8.300000
# 9          Cobble Hill        8.066667
# 13         Morris Park        8.500000
# 16      Pelham Gardens        8.400000
# 19            Woodlawn        8.600000

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,ny_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]
ny_neighborhood_stats
# Out:
#     Borough        Neighborhood   Latitude  Longitude  Average Rating
# 0  Brooklyn  Bedford Stuyvesant  40.687232 -73.941785        9.200000
# 1  Brooklyn            Bushwick  40.698116 -73.925258        9.200000
# 2     Bronx         City Island  40.847247 -73.786488        8.300000
# 3  Brooklyn         Cobble Hill  40.687920 -73.998561        8.066667
# 4     Bronx         Morris Park  40.847549 -73.850402        8.500000
# 5     Bronx      Pelham Gardens  40.862966 -73.841612        8.400000
# 6     Bronx            Woodlawn  40.898273 -73.867315        8.600000

# %%
# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)
# instantiate a feature group for the ratings in the dataframe
rating = folium.map.FeatureGroup()

# loop through the ratings and add each to the neighborhood feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    rating.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add ratings to map
ny_map.add_child(rating)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_eb9f6462f0c147c39c1dd311aa1559ac%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eb9f6462f0c147c39c1dd311aa1559ac%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_eb9f6462f0c147c39c1dd311aa1559ac%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_eb9f6462f0c147c39c1dd311aa1559ac%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7127281%2C-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...
